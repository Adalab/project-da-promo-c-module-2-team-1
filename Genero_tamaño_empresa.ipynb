# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew
import scipy.stats as st

# %%
df_formacion_empresa=pd.read_csv('df_a_usar_2.csv')

# %%
df_formacion_empresa
# Out:
#        Unnamed: 0  index  time    age gender                country_q3  \
# 0               0      0   910  50-54    Man                     India
# 1               1      1   784  50-54    Man                 Indonesia
# 2               2      2   924  22-24    Man                  Pakistan
# 3               3      3   575  45-49    Man                    Mexico
# 4               4      4   781  45-49    Man                     India
# ...           ...    ...   ...    ...    ...                       ...
# 25968       25968  25968  1756  30-34    Man                     Egypt
# 25969       25969  25969   253  22-24    Man                     China
# 25970       25970  25970   494  50-54    Man                    Sweden
# 25971       25971  25971   277  45-49    Man  United States of America
# 25972       25972  25972   255  18-21    Man                     India
#
#             education_q4                  role_q5              experience_q6  \
# 0      Bachelor’s degree                    Other                 5-10 years
# 1        Master’s degree  Program/Project Manager                  20+ years
# 2        Master’s degree        Software Engineer                  1-3 years
# 3        Doctoral degree       Research Scientist                  20+ years
# 4        Doctoral degree                    Other                  < 1 years
# ...                  ...                      ...                        ...
# 25968  Bachelor’s degree             Data Analyst                  1-3 years
# 25969    Master’s degree                  Student                  1-3 years
# 25970    Doctoral degree       Research Scientist  I have never written code
# 25971    Master’s degree           Data Scientist                 5-10 years
# 25972  Bachelor’s degree         Business Analyst  I have never written code
#
#            Q8  ... Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6  \
# 0      Python  ...          NaN          NaN            NaN          NaN
# 1      Python  ...          NaN          NaN            NaN          NaN
# 2      Python  ...          NaN          NaN   TensorBoard           NaN
# 3      Python  ...          NaN          NaN            NaN          NaN
# 4      Python  ...          NaN          NaN            NaN          NaN
# ...       ...  ...          ...          ...            ...          ...
# 25968  Python  ...          NaN          NaN            NaN          NaN
# 25969  Python  ...          NaN          NaN            NaN          NaN
# 25970     NaN  ...          NaN          NaN            NaN          NaN
# 25971  Python  ...          NaN          NaN            NaN          NaN
# 25972     NaN  ...          NaN          NaN            NaN          NaN
#
#       Q38_B_Part_7 Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11  \
# 0              NaN          NaN          NaN           NaN           NaN
# 1              NaN          NaN          NaN           NaN          None
# 2              NaN          NaN          NaN           NaN           NaN
# 3              NaN          NaN          NaN           NaN          None
# 4              NaN          NaN          NaN           NaN           NaN
# ...            ...          ...          ...           ...           ...
# 25968          NaN          NaN          NaN           NaN           NaN
# 25969          NaN          NaN          NaN           NaN           NaN
# 25970          NaN          NaN          NaN           NaN          None
# 25971          NaN          NaN          NaN           NaN           NaN
# 25972          NaN          NaN          NaN           NaN          None
#
#       Q38_B_OTHER
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 25968         NaN
# 25969         NaN
# 25970         NaN
# 25971         NaN
# 25972         NaN
#
# [25973 rows x 243 columns]

# %%
df_genero=df_formacion_empresa.loc[:,[ 'index','time', 'age', 'gender','education_q4','sector_q20','experience_q6','company_size_q21','role_q5','anual_income_q25']]
df_genero
#Reduzco el DataFrame a nuestras columnas de interés
# Out:
#        index  time    age gender       education_q4  \
# 0          0   910  50-54    Man  Bachelor’s degree
# 1          1   784  50-54    Man    Master’s degree
# 2          2   924  22-24    Man    Master’s degree
# 3          3   575  45-49    Man    Doctoral degree
# 4          4   781  45-49    Man    Doctoral degree
# ...      ...   ...    ...    ...                ...
# 25968  25968  1756  30-34    Man  Bachelor’s degree
# 25969  25969   253  22-24    Man    Master’s degree
# 25970  25970   494  50-54    Man    Doctoral degree
# 25971  25971   277  45-49    Man    Master’s degree
# 25972  25972   255  18-21    Man  Bachelor’s degree
#
#                                    sector_q20              experience_q6  \
# 0                   Manufacturing/Fabrication                 5-10 years
# 1                   Manufacturing/Fabrication                  20+ years
# 2                         Academics/Education                  1-3 years
# 3                         Academics/Education                  20+ years
# 4                         Academics/Education                  < 1 years
# ...                                       ...                        ...
# 25968                    Computers/Technology                  1-3 years
# 25969                                     NaN                  1-3 years
# 25970                     Academics/Education  I have never written code
# 25971  Online Service/Internet-based Services                 5-10 years
# 25972                                   Other  I have never written code
#
#                company_size_q21                  role_q5 anual_income_q25
# 0              50-249 employees                    Other    25,000-29,999
# 1          1000-9,999 employees  Program/Project Manager    60,000-69,999
# 2          1000-9,999 employees        Software Engineer           $0-999
# 3          1000-9,999 employees       Research Scientist    30,000-39,999
# 4              50-249 employees                    Other    30,000-39,999
# ...                         ...                      ...              ...
# 25968  10,000 or more employees             Data Analyst    15,000-19,999
# 25969                       NaN                  Student              NaN
# 25970      1000-9,999 employees       Research Scientist           $0-999
# 25971  10,000 or more employees           Data Scientist              NaN
# 25972            0-49 employees         Business Analyst           $0-999
#
# [25973 rows x 10 columns]

# %%
df_genero['company_size_q21'].isnull().sum()
#averiguo los nulos
# Out:
# 9722

# %%
df_de_nulos=df_genero[df_genero['company_size_q21'].isna()]
df_de_nulos
# me hago DataFrame para poder estudiarlo un poco
# Out:
#        index   time    age gender  \
# 5          5   1020  25-29  Woman
# 6          6    141  18-21  Woman
# 8          8   1744  22-24    Man
# 11        11   3081  18-21  Woman
# 12        12   1922  18-21  Woman
# ...      ...    ...    ...    ...
# 25951  25951    723  22-24    Man
# 25956  25956  25145  40-44    Man
# 25964  25964    484  22-24    Man
# 25965  25965  40250  18-21    Man
# 25969  25969    253  22-24    Man
#
#                                             education_q4 sector_q20  \
# 5                                 I prefer not to answer        NaN
# 6      Some college/university study without earning ...        NaN
# 8                                      Bachelor’s degree        NaN
# 11                                       Master’s degree        NaN
# 12                                       Master’s degree        NaN
# ...                                                  ...        ...
# 25951                                    Master’s degree        NaN
# 25956                                    Doctoral degree        NaN
# 25964                                  Bachelor’s degree        NaN
# 25965                                    Master’s degree        NaN
# 25969                                    Master’s degree        NaN
#
#       experience_q6 company_size_q21                 role_q5 anual_income_q25
# 5         < 1 years              NaN  Currently not employed              NaN
# 6         1-3 years              NaN                 Student              NaN
# 8         3-5 years              NaN  Currently not employed              NaN
# 11        < 1 years              NaN                 Student              NaN
# 12        < 1 years              NaN                 Student              NaN
# ...             ...              ...                     ...              ...
# 25951     1-3 years              NaN                 Student              NaN
# 25956   10-20 years              NaN      Research Scientist              NaN
# 25964    5-10 years              NaN                 Student              NaN
# 25965     1-3 years              NaN            Data Analyst              NaN
# 25969     1-3 years              NaN                 Student              NaN
#
# [9722 rows x 10 columns]

# %%
df_de_nulos['role_q5'].value_counts()
#casi todos son desempleados o estudiantes casi 9000
# Out:
# Student                         6804
# Currently not employed          1986
# Software Engineer                191
# Data Scientist                   180
# Data Analyst                     130
# Machine Learning Engineer        102
# Other                             89
# Research Scientist                65
# Business Analyst                  47
# Data Engineer                     38
# Program/Project Manager           33
# Product Manager                   17
# Statistician                      17
# DBA/Database Engineer             13
# Developer Relations/Advocacy      10
# Name: role_q5, dtype: int64

# %%
df_de_nulos['anual_income_q25'].value_counts()
#en los nulos, como era de esperar, no hay salarios
# Out:
# Series([], Name: anual_income_q25, dtype: int64)

# %%
#podriamos apurar todas las graficas quitando varones, que los minoritarios no se ven :((

# %%
plt.figure(figsize = (10,5))  # establecemos el tamaño de la gráfica
sns.countplot(data =df_genero, x = "company_size_q21", hue = "gender") # hacemos el countplot.
plt.xticks(rotation = 45) # rotamos las etiquetas del eje x para que estén a 45 grados
plt.legend( bbox_to_anchor=(1, 0.5));  # movemos la leyenda para colocarla fuera del plot.

# %%
plt.figure(figsize =(10,8))
sns.histplot(x=df_genero['company_size_q21'],data = df_genero, hue='gender', kde=True)
plt.xticks(rotation= 75)
plt.show()
#Representacion por tamaño de empresa de la cantidad de individuos según la identidad de género

# %%
df_genero['anual_income_q25'].value_counts()
# Out:
# $0-999              3369
# 1,000-1,999          969
# 10,000-14,999        950
# 30,000-39,999        741
# 100,000-124,999      725
# 5,000-7,499          699
# 50,000-59,999        697
# 40,000-49,999        688
# 20,000-24,999        587
# 2,000-2,999          575
# 15,000-19,999        573
# 7,500-9,999          552
# 60,000-69,999        551
# 25,000-29,999        470
# 70,000-79,999        464
# 4,000-4,999          456
# 150,000-199,999      392
# 80,000-89,999        391
# 3,000-3,999          380
# 125,000-149,999      379
# 90,000-99,999        350
# 200,000-249,999      177
# 300,000-499,999       91
# 250,000-299,999       75
# >$1,000,000           58
# $500,000-999,999      32
# Name: anual_income_q25, dtype: int64

# %%
df_genero.isnull().sum()
#compruebo nulos de las columnas, para saber cuantos datos perderé por nulos, en este caso 9722 del total porque género no tiene nulos
# Out:
# index                   0
# time                    0
# age                     0
# gender                  0
# education_q4            0
# sector_q20           9648
# experience_q6           0
# company_size_q21     9722
# role_q5                 0
# anual_income_q25    10582
# dtype: int64

# %%
df_genero['company_size_q21'].value_counts()
#
# Out:
# 0-49 employees              5055
# 10,000 or more employees    3416
# 1000-9,999 employees        3059
# 50-249 employees            2567
# 250-999 employees           2154
# Name: company_size_q21, dtype: int64

# %%
genero_empresa=pd.DataFrame(df_genero.groupby(['company_size_q21'])['gender'].value_counts())
genero_empresa
#Agrupo los datos en un Dataframe en el que enfrento mis dos variables :género y temaño de empresa
# Out:
#                                                   gender
# company_size_q21         gender
# 0-49 employees           Man                        4110
#                          Woman                       841
#                          Prefer not to say            79
#                          Nonbinary                    18
#                          Prefer to self-describe       7
# 10,000 or more employees Man                        2818
#                          Woman                       538
#                          Prefer not to say            44
#                          Nonbinary                     9
#                          Prefer to self-describe       7
# 1000-9,999 employees     Man                        2530
#                          Woman                       476
#                          Prefer not to say            36
#                          Nonbinary                    12
#                          Prefer to self-describe       5
# 250-999 employees        Man                        1742
#                          Woman                       377
#                          Prefer not to say            28
#                          Prefer to self-describe       4
#                          Nonbinary                     3
# 50-249 employees         Man                        2097
#                          Woman                       435
#                          Prefer not to say            26
#                          Nonbinary                     7
#                          Prefer to self-describe       2

# %%
genero_empresa.rename(columns={'gender':'frecuencia'}, inplace= True)
genero_empresa.reset_index()
#reordeno Dataframe
# Out:
#             company_size_q21                   gender  frecuencia
# 0             0-49 employees                      Man        4110
# 1             0-49 employees                    Woman         841
# 2             0-49 employees        Prefer not to say          79
# 3             0-49 employees                Nonbinary          18
# 4             0-49 employees  Prefer to self-describe           7
# 5   10,000 or more employees                      Man        2818
# 6   10,000 or more employees                    Woman         538
# 7   10,000 or more employees        Prefer not to say          44
# 8   10,000 or more employees                Nonbinary           9
# 9   10,000 or more employees  Prefer to self-describe           7
# 10      1000-9,999 employees                      Man        2530
# 11      1000-9,999 employees                    Woman         476
# 12      1000-9,999 employees        Prefer not to say          36
# 13      1000-9,999 employees                Nonbinary          12
# 14      1000-9,999 employees  Prefer to self-describe           5
# 15         250-999 employees                      Man        1742
# 16         250-999 employees                    Woman         377
# 17         250-999 employees        Prefer not to say          28
# 18         250-999 employees  Prefer to self-describe           4
# 19         250-999 employees                Nonbinary           3
# 20          50-249 employees                      Man        2097
# 21          50-249 employees                    Woman         435
# 22          50-249 employees        Prefer not to say          26
# 23          50-249 employees                Nonbinary           7
# 24          50-249 employees  Prefer to self-describe           2

# %%
tamaño_genero=pd.DataFrame(pd.crosstab(df_genero['company_size_q21'], df_genero['gender']))
tamaño_genero
#Hago tabla de frecuencias de las variables
# Out:
# gender                     Man  Nonbinary  Prefer not to say  \
# company_size_q21
# 0-49 employees            4110         18                 79
# 10,000 or more employees  2818          9                 44
# 1000-9,999 employees      2530         12                 36
# 250-999 employees         1742          3                 28
# 50-249 employees          2097          7                 26
#
# gender                    Prefer to self-describe  Woman
# company_size_q21
# 0-49 employees                                  7    841
# 10,000 or more employees                        7    538
# 1000-9,999 employees                            5    476
# 250-999 employees                               4    377
# 50-249 employees                                2    435

# %% [markdown]
# quita nulos, asi que nos quedan 16251 registros

# %% [markdown]
# A partir de aqui, convierto en arrays mis columnas, para hacer porcentajes y posibles operaciones aritmeticas

# %%
mujer=np.array(tamaño_genero['Woman'])
mujer
# Out:
# array([841, 538, 476, 377, 435])

# %%
def porcentaje(array):
    array2=[]
    for i in array:
    #print(i)
        z=i*100/array.sum()
        array2.append(z)
    return np.round(np.array(array2), decimals=2)
    #funcion para hallar porcentajes
    #print(z)

# %%
#tamaño_genero["Woman%"] =tamaño_genero_porcentaje (tamaño_genero["'Woman"].apply(porcentaje))

# %%
mujer2=porcentaje(mujer)
mujer2
# Out:
# array([31.53, 20.17, 17.85, 14.14, 16.31])

# %%
tamaño_genero['Woman']=mujer2

# %%
hombre=np.array(tamaño_genero['Man'])

# %%
hombre2=porcentaje(hombre)

# %%
tamaño_genero['Man']=hombre2

# %%
autodeterminados=np.array(tamaño_genero['Prefer to self-describe'])

# %%
autodeterminados2=porcentaje(autodeterminados)

# %%
tamaño_genero['Prefer to self-describe']=autodeterminados2

# %%
no_decir=np.array(tamaño_genero['Prefer not to say'])

# %%
no_decir=porcentaje(no_decir)

# %%
tamaño_genero['Prefer not to say']=no_decir

# %%
nobinario=np.array(tamaño_genero['Nonbinary'])

# %%
nobinario=porcentaje(nobinario)

# %%
tamaño_genero['Nonbinary']=nobinario

# %%
tamaño_genero
#reconstruyo mi dataframe con los porcentajes, cada porcentaje, se resiere a si mismo, no al tamaño de la empresa, 
# quedamos que debido al sesgo seria mas facil comparar entre ellos mismos, asi, nos sale la prob. de q siendo mujer, estes en un tipo de 
# empresa u otro por ejemplo.
# Out:
# gender                      Man  Nonbinary  Prefer not to say  \
# company_size_q21
# 0-49 employees            30.91      36.73              37.09
# 10,000 or more employees  21.19      18.37              20.66
# 1000-9,999 employees      19.03      24.49              16.90
# 250-999 employees         13.10       6.12              13.15
# 50-249 employees          15.77      14.29              12.21
#
# gender                    Prefer to self-describe  Woman
# company_size_q21
# 0-49 employees                               28.0  31.53
# 10,000 or more employees                     28.0  20.17
# 1000-9,999 employees                         20.0  17.85
# 250-999 employees                            16.0  14.14
# 50-249 employees                              8.0  16.31

# %%
tamaño_gen_est=tamaño_genero.reset_index()
tamaño_gen_est
# Out:
# gender          company_size_q21    Man  Nonbinary  Prefer not to say  \
# 0                 0-49 employees  30.91      36.73              37.09
# 1       10,000 or more employees  21.19      18.37              20.66
# 2           1000-9,999 employees  19.03      24.49              16.90
# 3              250-999 employees  13.10       6.12              13.15
# 4               50-249 employees  15.77      14.29              12.21
#
# gender  Prefer to self-describe  Woman
# 0                          28.0  31.53
# 1                          28.0  20.17
# 2                          20.0  17.85
# 3                          16.0  14.14
# 4                           8.0  16.31

# %%
tamaño_gen_est.columns
# Out:
# Index(['company_size_q21', 'Man', 'Nonbinary', 'Prefer not to say',
#        'Prefer to self-describe', 'Woman'],
#       dtype='object', name='gender')

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x=tamaño_gen_est['company_size_q21'],y=tamaño_gen_est['Man'], label = 'Man', linewidth = 4, color = 'blue')
sns.lineplot(x=tamaño_gen_est['company_size_q21'],y=tamaño_gen_est['Woman'], label = 'Woman', linewidth = 4, color = 'green')
sns.lineplot(x=tamaño_gen_est['company_size_q21'],y=tamaño_gen_est['Nonbinary'], label = 'Nonbinary', linewidth = 4, color = 'red')
sns.lineplot(x=tamaño_gen_est['company_size_q21'],y=tamaño_gen_est['Prefer not to say'], label = 'Prefer not to say', linewidth = 4, color = 'orange')
sns.lineplot(x=tamaño_gen_est['company_size_q21'],y=tamaño_gen_est['Prefer to self-describe'], label = 'Prefer to self-describe', linewidth = 4, color = 'violet')
plt.xticks(rotation= 45)
plt.ylabel('Porcentaje sgún identidades de género')
plt.xlabel('Tamaño de empresa')
plt.show()
#representacion de porcentajes

# %% [markdown]
# **Hombres, mujeres y presumiblemente asemejados a binarios (prefieren no definirse), se distribuyen de forma bastante igual entre los diferentes tamaños de empresa. Las identidades de género no tan binarias, son las que tienen una distribución más desigual hacia pequeña y mediana empresa.**

# %% [markdown]
# No se si tiene mucho sentido averiguar sesgos , media, varianza, y/o confianza.

# %%
#histogramas de cada genero segun el tamaño de la empresa (genero_empresa['company_size_q21'])(genero_empresa['gender']=='Man')
