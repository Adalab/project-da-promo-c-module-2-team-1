# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sidetable

# %% [markdown]
# # Edad(Q1) Salario(Q25)

# %%
df = pd.read_csv('../files/df_a_usar_2.csv', index_col = 0)

# %%
df.shape
# Out:
# (25973, 242)

# %%
df_as = df.copy()
df_as.head(2)
# Out:
#    index  time    age gender country_q3       education_q4  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
#
#                    role_q5 experience_q6      Q8  \
# 0                    Other    5-10 years  Python
# 1  Program/Project Manager     20+ years  Python
#
#                                                  Q11  ... Q38_B_Part_3  \
# 0                                           A laptop  ...          NaN
# 1  A cloud computing platform (AWS, Azure, GCP, h...  ...          NaN
#
#   Q38_B_Part_4 Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7 Q38_B_Part_8  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#   Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 0          NaN           NaN           NaN         NaN
# 1          NaN           NaN          None         NaN
#
# [2 rows x 242 columns]

# %%
# mantenemos la columna index como tal.
df_as= df_as.set_index('index')
df_as.head(2)
# Out:
#        time    age gender country_q3       education_q4  \
# index
# 0       910  50-54    Man      India  Bachelor’s degree
# 1       784  50-54    Man  Indonesia    Master’s degree
#
#                        role_q5 experience_q6      Q8  \
# index
# 0                        Other    5-10 years  Python
# 1      Program/Project Manager     20+ years  Python
#
#                                                      Q11        Q13  ...  \
# index                                                                ...
# 0                                               A laptop  2-5 times  ...
# 1      A cloud computing platform (AWS, Azure, GCP, h...      Never  ...
#
#       Q38_B_Part_3 Q38_B_Part_4 Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
#
#       Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# index
# 0              NaN          NaN           NaN           NaN         NaN
# 1              NaN          NaN           NaN          None         NaN
#
# [2 rows x 241 columns]

# %% [markdown]
# #  Limpieza

# %% [markdown]
# - Eliminar las columnas que no nos interesan

# %%
# hay muchas columnas que no interesan, visualizamos y eliminamos:
df_as.columns

# %%
df_as = df_as.drop(columns =['Q26', 'Q33', 'Q35', 'Q41', 'Q9',  'Q12', 'Q14', 'Q16', 'Q17', 'Q24','Q32', 'Q34','Q18_Part_1',
 'Q18_Part_2', 'Q18_Part_3', 'Q18_Part_4','Q18_Part_5','Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1', 'Q19_Part_2', 'Q19_Part_3',
 'Q19_Part_4', 'Q19_Part_5', 'Q19_OTHER','Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3', 'Q27_A_Part_4', 'Q27_A_Part_5',
 'Q27_A_Part_6', 'Q27_A_Part_7', 'Q27_A_Part_8', 'Q27_A_Part_9', 'Q27_A_Part_10', 'Q27_A_Part_11', 'Q27_A_OTHER',
 'Q28', 'Q29_A_Part_1', 'Q29_A_Part_2', 'Q29_A_Part_3', 'Q29_A_Part_4', 'Q29_A_OTHER', 'Q30_A_Part_1','Q30_A_Part_2',
 'Q30_A_Part_3','Q30_A_Part_4', 'Q30_A_Part_5', 'Q30_A_Part_6', 'Q30_A_Part_7', 'Q30_A_OTHER', 'Q31_A_Part_1',
 'Q31_A_Part_2', 'Q31_A_Part_3', 'Q31_A_Part_4', 'Q31_A_Part_5', 'Q31_A_Part_6', 'Q31_A_Part_7', 'Q31_A_Part_8',
 'Q31_A_Part_9', 'Q31_A_OTHER', 'Q36_A_Part_1', 'Q36_A_Part_2', 'Q36_A_Part_3', 'Q36_A_Part_4', 'Q36_A_Part_5',
 'Q36_A_Part_6', 'Q36_A_Part_7', 'Q36_A_OTHER','Q37_A_Part_1', 'Q37_A_Part_2', 'Q37_A_Part_3', 'Q37_A_Part_4',
 'Q37_A_Part_5', 'Q37_A_Part_6', 'Q37_A_Part_7', 'Q37_A_OTHER', 'Q38_A_Part_1','Q38_A_Part_2', 'Q38_A_Part_3',
 'Q38_A_Part_4', 'Q38_A_Part_5', 'Q38_A_Part_6', 'Q38_A_Part_7', 'Q38_A_Part_8', 'Q38_A_Part_9', 'Q38_A_Part_10',
 'Q38_A_Part_11', 'Q38_A_OTHER', 'Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_4', 'Q39_Part_5', 'Q39_Part_6',
 'Q39_Part_7', 'Q39_Part_8', 'Q39_Part_9', 'Q39_OTHER', 'Q40_Part_1', 'Q40_Part_2', 'Q40_Part_3', 'Q40_Part_4',
 'Q40_Part_5', 'Q40_Part_6', 'Q40_Part_7', 'Q40_Part_8', 'Q40_Part_9', 'Q40_Part_10', 'Q40_Part_11', 'Q40_OTHER',
 'Q42_Part_1', 'Q42_Part_2', 'Q42_Part_3', 'Q42_Part_4', 'Q42_Part_5', 'Q42_Part_6', 'Q42_Part_7', 'Q42_Part_8',
 'Q42_Part_9', 'Q42_Part_10', 'Q42_Part_11', 'Q42_OTHER', 'Q27_B_Part_1', 'Q27_B_Part_2', 'Q27_B_Part_3', 'Q27_B_Part_4',
 'Q27_B_Part_5', 'Q27_B_Part_6', 'Q27_B_Part_7', 'Q27_B_Part_8', 'Q27_B_Part_9', 'Q27_B_Part_10', 'Q27_B_Part_11',
 'Q27_B_OTHER',
 'Q29_B_Part_1',
 'Q29_B_Part_2',
 'Q29_B_Part_3',
 'Q29_B_Part_4',
 'Q29_B_OTHER',
 'Q30_B_Part_1',
 'Q30_B_Part_2',
 'Q30_B_Part_3',
 'Q30_B_Part_4',
 'Q30_B_Part_5',
 'Q30_B_Part_6',
 'Q30_B_Part_7',
 'Q30_B_OTHER',
 'Q31_B_Part_1',
 'Q31_B_Part_2',
 'Q31_B_Part_3',
 'Q31_B_Part_4',
 'Q31_B_Part_5',
 'Q31_B_Part_6',
 'Q31_B_Part_7',
 'Q31_B_Part_8',
 'Q31_B_Part_9',
 'Q31_B_OTHER',
 'Q32_B_Part_1',
 'Q32_B_Part_2',
 'Q32_B_Part_3',
 'Q32_B_Part_4',
 'Q32_B_Part_5',
 'Q32_B_Part_6',
 'Q32_B_Part_7',
 'Q32_B_Part_8',
 'Q32_B_Part_9',
 'Q32_B_Part_10',
 'Q32_B_Part_11',
 'Q32_B_Part_12',
 'Q32_B_Part_13',
 'Q32_B_Part_14',
 'Q32_B_Part_15',
 'Q32_B_Part_16',
 'Q32_B_Part_17',
 'Q32_B_Part_18',
 'Q32_B_Part_19',
 'Q32_B_Part_20',
 'Q32_B_OTHER',
 'Q34_B_Part_1',
 'Q34_B_Part_2',
 'Q34_B_Part_3',
 'Q34_B_Part_4',
 'Q34_B_Part_5',
 'Q34_B_Part_6',
 'Q34_B_Part_7',
 'Q34_B_Part_8',
 'Q34_B_Part_9',
 'Q34_B_Part_10',
 'Q34_B_Part_11',
 'Q34_B_Part_12',
 'Q34_B_Part_13',
 'Q34_B_Part_14',
 'Q34_B_Part_15',
 'Q34_B_Part_16',
 'Q34_B_OTHER',
 'Q36_B_Part_1',
 'Q36_B_Part_2',
 'Q36_B_Part_3',
 'Q36_B_Part_4',
 'Q36_B_Part_5',
 'Q36_B_Part_6',
 'Q36_B_Part_7',
 'Q36_B_OTHER',
 'Q37_B_Part_1',
 'Q37_B_Part_2',
 'Q37_B_Part_3',
 'Q37_B_Part_4',
 'Q37_B_Part_5',
 'Q37_B_Part_6',
 'Q37_B_Part_7',
 'Q37_B_OTHER',
 'Q38_B_Part_1',
 'Q38_B_Part_2',
 'Q38_B_Part_3',
 'Q38_B_Part_4',
 'Q38_B_Part_5',
 'Q38_B_Part_6',
 'Q38_B_Part_7',
 'Q38_B_Part_8',
 'Q38_B_Part_9',
 'Q38_B_Part_10',
 'Q38_B_Part_11',
 'Q38_B_OTHER'])

# %%
# algunas columnas que faltan eliminarlas
df_as = df_as.drop(columns =['Q8', 'Q11', 'Q13', 'Q15', 'Q22', 'Q23', 'Q7'])

# %% [markdown]
# Columna gender
# - Fusionamos las categorias 'Nonbinary' y 'Prefer to self-describe' (depuración Gadea)

# %%
# fusionamos las categorias 'Nonbinary' y 'Prefer to self-describe' (depuración Gadea)
df_as['gender'] = df_as['gender'].replace({'Prefer to self-describe': 'NB', 'Nonbinary': 'NB', 'Prefer not to say': np.nan})
df_as['gender'].value_counts()
# Out:
# Man      20598
# Woman     4890
# NB         130
# Name: gender, dtype: int64

# %% [markdown]
# Columna salario q25:
# - Vemos que annual_income_q25 presenta valores en dólares y los pasamos a euros.
# - Añadimos una nueva columna - 'annual_incom€_q25' - que son los rangos en dólares de los salários convertidos a euros.
# -Rectificamos el nombre de la columna

# %%
# rectificación nombre columna
df_as.rename(columns = {'anual_income_q25' : 'annual_income_q25'}, inplace = True)

# %%
# quitamos '$' 
df_as['annual_income_q25'] = df_as['annual_income_q25'].replace('$0-999','0-999')
df_as['annual_income_q25'] = df_as['annual_income_q25'].replace('>$1,000,000','>1,000,000')

# %%
df_as['annual_income_q25'].unique()
# Out:
# array(['25,000-29,999', '60,000-69,999', '0-999', '30,000-39,999', nan,
#        '15,000-19,999', '70,000-79,999', '2,000-2,999', '10,000-14,999',
#        '5,000-7,499', '20,000-24,999', '1,000-1,999', '100,000-124,999',
#        '7,500-9,999', '4,000-4,999', '40,000-49,999', '50,000-59,999',
#        '3,000-3,999', '300,000-499,999', '200,000-249,999',
#        '125,000-149,999', '250,000-299,999', '80,000-89,999',
#        '90,000-99,999', '150,000-199,999', '>1,000,000',
#        '$500,000-999,999'], dtype=object)

# %%
# lista con valores originales ['annual_income_q25']:

list_income = ['25,000-29,999', '60,000-69,999', '0-999', '30,000-39,999', np.nan,
       '15,000-19,999', '70,000-79,999', '2,000-2,999', '10,000-14,999',
       '5,000-7,499', '20,000-24,999', '1,000-1,999', '100,000-124,999',
       '7,500-9,999', '4,000-4,999', '40,000-49,999', '50,000-59,999',
       '3,000-3,999', '300,000-499,999', '200,000-249,999',
       '125,000-149,999', '250,000-299,999', '80,000-89,999',
       '90,000-99,999', '150,000-199,999', '>1,000,000',
       '$500,000-999,999']

# %%
# list = list_income sin rangos.

exchange_rate = 0.93            # fuente : https://www.oanda.com/currency-converter/en/?from=USD&to=EUR&amount=1  , 11.ene.23

new_list = []
list = [25000,29999, 60.000,69.999, 0000,999, 30.000,39.999, np.nan,
       15.000,19.999, 70.000,79.999, 2.000,2.999, 10.000,14.999,
       5.000,7.499, 20.000,24.999, 1.000,1.999, 100.000,124.999,
       7.500,9.999, 4.000,4.999, 40.000,49.999, 50.000,59.999,
       3.000,3.999, 300.000,499.999, 200.000,249.999,
       125.000,149.999, 250.000,299.999, 80.000,89.999,
       90.000,99.999, 150.000,199.999, 1.000000,
       500.000,999.999]                             
for i in list:
        new_list.append((i*exchange_rate))
print(new_list)
# Out:
# [23250.0, 27899.07, 55.800000000000004, 65.09907, 0.0, 929.07, 27.900000000000002, 37.199070000000006, nan, 13.950000000000001, 18.59907, 65.10000000000001, 74.39907, 1.86, 2.78907, 9.3, 13.94907, 4.65, 6.97407, 18.6, 23.24907, 0.93, 1.8590700000000002, 93.0, 116.24907, 6.9750000000000005, 9.29907, 3.72, 4.64907, 37.2, 46.49907, 46.5, 55.79907000000001, 2.79, 3.7190700000000003, 279.0, 464.9990700000001, 186.0, 232.49907000000002, 116.25, 139.49907, 232.5, 278.99907, 74.4, 83.69907, 83.7, 92.99907, 139.5, 185.99907000000002, 0.93, 465.0, 929.9990700000001]

# %%
# lista con los valores del los rangos [annual_income_q25] convertidos a euros:
list_income_new = ['23,250-27,899', '55,800-65,099', '0-929,07', '27,900-37,199', np.nan,
                   '13,950-18,599', '65,100-74,399', '1,860-2,789', '9,300-13,949',
                   '4,650-6,974', '18,600-23,249', '930-1,859', '93,000-116,249',
                   '6,975-9,299', '3,720-4,649', '37,200-46,499', '46,500-55,799',
                   '2,790-3,719', '279,000-464,999', '186,000-232,499',
                   '116,250-139,499', '232,500-278,999', '74,400-83,699', '83,700-92,999', '139,500-185,999', '>930,000',
                   '465,000-929,999']

# %%
# creamos la nueva columna:
df_as['annual_incom€_q25'] = df_as['annual_income_q25'].replace(list_income, list_income_new)

# %%
df_as['annual_incom€_q25'].unique()
# Out:
# array(['23,250-27,899', '55,800-65,099', '0-929,07', '27,900-37,199', nan,
#        '13,950-18,599', '65,100-74,399', '1,860-2,789', '9,300-13,949',
#        '4,650-6,974', '18,600-23,249', '930-1,859', '93,000-116,249',
#        '6,975-9,299', '3,720-4,649', '37,200-46,499', '46,500-55,799',
#        '2,790-3,719', '279,000-464,999', '186,000-232,499',
#        '116,250-139,499', '232,500-278,999', '74,400-83,699',
#        '83,700-92,999', '139,500-185,999', '>930,000', '465,000-929,999'],
#       dtype=object)

# %% [markdown]
# # Depurando

# %% [markdown]
# Tenemos:
# - en la categoria edad : 11 intervalos por rango de edad
# - en la categpria salario : 26 intervalos por rangos salariales

# %%
df_as.groupby('gender').ngroups, df_as.groupby('age').ngroups, df_as.groupby('annual_incom€_q25').ngroups
# Out:
# (3, 11, 26)

# %%
df_as.shape
# Out:
# (25973, 11)

# %%
df_as.head(3).T
# Out:
# index                                      0                          1  \
# time                                     910                        784
# age                                    50-54                      50-54
# gender                                   Man                        Man
# country_q3                             India                  Indonesia
# education_q4               Bachelor’s degree            Master’s degree
# role_q5                                Other    Program/Project Manager
# experience_q6                     5-10 years                  20+ years
# sector_q20         Manufacturing/Fabrication  Manufacturing/Fabrication
# company_size_q21            50-249 employees       1000-9,999 employees
# annual_income_q25              25,000-29,999              60,000-69,999
# annual_incom€_q25              23,250-27,899              55,800-65,099
#
# index                                 2
# time                                924
# age                               22-24
# gender                              Man
# country_q3                     Pakistan
# education_q4            Master’s degree
# role_q5               Software Engineer
# experience_q6                 1-3 years
# sector_q20          Academics/Education
# company_size_q21   1000-9,999 employees
# annual_income_q25                 0-999
# annual_incom€_q25              0-929,07

# %% [markdown]
# Nulos

# %%
# percentaje de valores nulos 
nulls = pd.DataFrame((df_as.isnull().sum() * 100) / df.shape[0]).reset_index()
nulls.head(17)
# Out:
#                 index          0
# 0                time   0.000000
# 1                 age   0.000000
# 2              gender   1.366804
# 3          country_q3   0.000000
# 4        education_q4   0.000000
# 5             role_q5   0.000000
# 6       experience_q6   0.000000
# 7          sector_q20  37.146267
# 8    company_size_q21  37.431179
# 9   annual_income_q25  40.742309
# 10  annual_incom€_q25  40.742309

# %%
df_as['annual_incom€_q25'].isnull().sum()
# Out:
# 10582

# %%
income= df_as['annual_incom€_q25'].value_counts().reset_index()
income.columns = ['IncomeBin', 'Count']
income
# Out:
#           IncomeBin  Count
# 0          0-929,07   3369
# 1         930-1,859    969
# 2      9,300-13,949    950
# 3     27,900-37,199    741
# 4    93,000-116,249    725
# 5       4,650-6,974    699
# 6     46,500-55,799    697
# 7     37,200-46,499    688
# 8     18,600-23,249    587
# 9       1,860-2,789    575
# 10    13,950-18,599    573
# 11      6,975-9,299    552
# 12    55,800-65,099    551
# 13    23,250-27,899    470
# 14    65,100-74,399    464
# 15      3,720-4,649    456
# 16  139,500-185,999    392
# 17    74,400-83,699    391
# 18      2,790-3,719    380
# 19  116,250-139,499    379
# 20    83,700-92,999    350
# 21  186,000-232,499    177
# 22  279,000-464,999     91
# 23  232,500-278,999     75
# 24         >930,000     58
# 25  465,000-929,999     32

# %%
age= df_as['age'].value_counts().reset_index()
age.columns = ['AgeBin', 'Count']
age
# Out:
#    AgeBin  Count
# 0   25-29   4931
# 1   18-21   4901
# 2   22-24   4694
# 3   30-34   3441
# 4   35-39   2504
# 5   40-44   1890
# 6   45-49   1375
# 7   50-54    964
# 8   55-59    592
# 9   60-69    553
# 10    70+    128

# %% [markdown]
#         - Dentro del conjunto de columnas de interés para nuestro estudio, vemos que existen nulos en las columnas sector_q20(37%), company_size:q21(37%), annual_income_q25(41% : equivalente a 10582 registros).

# %% [markdown]
#     -  Se puede observar que la grande mayoria está en un intervalo de los 18 a
#     los 24 años. Sendo el intervalo de 25 a 29 años el que comporta mayor cantidad de encuestados

# %% [markdown]
# _________________________________________________________________________________________________________________

# %%
df_income_country = pd.DataFrame(df_as.groupby(['annual_incom€_q25'])['country_q3'].value_counts())
df_income_country.head(20)

# %%
# observamos que los estudiantes están en mayor números en el estudio (6804 registros), y de eses, 
# 3542 tienen edad entre 18 y 21 años,lo que probablemente afectará la variable salario.
cross_age_role = pd.crosstab(index = df_as['age'], columns = df_as['role_q5'], margins = True).T
cross_age_role
# Out:
# age                           18-21  22-24  25-29  30-34  35-39  40-44  45-49  \
# role_q5
# Business Analyst                 45    119    200    170    135    107     72
# Currently not employed          140    444    514    264    185    138     97
# DBA/Database Engineer             9     20     17     30     22     21     11
# Data Analyst                    191    419    588    420    280    163    105
# Data Engineer                    41    114    146    104     92     66     45
# Data Scientist                  343    594    907    625    414    317    172
# Developer Relations/Advocacy      7     12     12     14     19      9      6
# Machine Learning Engineer       239    336    377    221    130     82     39
# Other                            52    190    410    418    360    275    250
# Product Manager                   5     15     37     61     52     56     39
# Program/Project Manager          12     32     80    115    134    143    153
# Research Scientist               32     95    260    290    222    209    136
# Software Engineer               228    444    512    372    284    183    170
# Statistician                     15     48     62     49     36     29     26
# Student                        3542   1812    809    288    139     92     54
# All                            4901   4694   4931   3441   2504   1890   1375
#
# age                           50-54  55-59  60-69  70+    All
# role_q5
# Business Analyst                 54     27     35    4    968
# Currently not employed           81     51     53   19   1986
# DBA/Database Engineer            18     10     12    1    171
# Data Analyst                     67     32     28    8   2301
# Data Engineer                    28     19     11    2    668
# Data Scientist                  117     66     50   11   3616
# Developer Relations/Advocacy     13      1      4    2     99
# Machine Learning Engineer        36     20     18    1   1499
# Other                           166    125    115   32   2393
# Product Manager                  34      8     11    1    319
# Program/Project Manager          77     51     46    6    849
# Research Scientist              125     75     76   18   1538
# Software Engineer               109     76     63    8   2449
# Statistician                     11     14     14    9    313
# Student                          28     17     17    6   6804
# All                             964    592    553  128  25973

# %%
income_freq = df_as.stb.freq(['annual_incom€_q25'], thresh=80)
income_freq
# Out:
#    annual_incom€_q25  count    percent  cumulative_count  cumulative_percent
# 0           0-929,07   3369  21.889416              3369           21.889416
# 1          930-1,859    969   6.295887              4338           28.185303
# 2       9,300-13,949    950   6.172438              5288           34.357742
# 3      27,900-37,199    741   4.814502              6029           39.172244
# 4     93,000-116,249    725   4.710545              6754           43.882789
# 5        4,650-6,974    699   4.541615              7453           48.424404
# 6      46,500-55,799    697   4.528621              8150           52.953024
# 7      37,200-46,499    688   4.470145              8838           57.423169
# 8      18,600-23,249    587   3.813917              9425           61.237087
# 9        1,860-2,789    575   3.735950             10000           64.973036
# 10     13,950-18,599    573   3.722955             10573           68.695991
# 11       6,975-9,299    552   3.586512             11125           72.282503
# 12     55,800-65,099    551   3.580014             11676           75.862517
# 13     23,250-27,899    470   3.053733             12146           78.916250
# 14            others   3245  21.083750             15391          100.000000

# %%
age_freq = df_as.stb.freq(['age'], thresh=80)
age_freq
# Out:
#       age  count    percent  cumulative_count  cumulative_percent
# 0   25-29   4931  18.985100              4931           18.985100
# 1   18-21   4901  18.869595              9832           37.854695
# 2   22-24   4694  18.072614             14526           55.927309
# 3   30-34   3441  13.248373             17967           69.175682
# 4   35-39   2504   9.640781             20471           78.816463
# 5  others   5502  21.183537             25973          100.000000

# %% [markdown]
# - curiosidad 'DataAnalyst'

# %%
df_analyst = df_as[df_as['role_q5'] == 'Data Analyst']
df_analyst
# Out:
#         time    age gender                country_q3  \
# index
# 16      1315  50-54    Man                   Belgium
# 32       171  22-24     NB  United States of America
# 33       744  30-34  Woman                     Egypt
# 46      1524  22-24    Man                     China
# 52       866  40-44    Man              South Africa
# ...      ...    ...    ...                       ...
# 25954    474  25-29    Man                     India
# 25959  96354  18-21    Man                     India
# 25965  40250  18-21    Man                     India
# 25966    323  30-34    Man                     India
# 25968   1756  30-34    Man                     Egypt
#
#                                             education_q4       role_q5  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
# 46     Some college/university study without earning ...  Data Analyst
# 52                                       Master’s degree  Data Analyst
# ...                                                  ...           ...
# 25954                             Professional doctorate  Data Analyst
# 25959                                  Bachelor’s degree  Data Analyst
# 25965                                    Master’s degree  Data Analyst
# 25966                                  Bachelor’s degree  Data Analyst
# 25968                                  Bachelor’s degree  Data Analyst
#
#       experience_q6                              sector_q20  \
# index
# 16        20+ years                           Energy/Mining
# 32        < 1 years               Manufacturing/Fabrication
# 33        3-5 years                      Non-profit/Service
# 46        < 1 years                    Computers/Technology
# 52        1-3 years               Manufacturing/Fabrication
# ...             ...                                     ...
# 25954     < 1 years  Online Service/Internet-based Services
# 25959     1-3 years                     Academics/Education
# 25965     1-3 years                                     NaN
# 25966     1-3 years               Manufacturing/Fabrication
# 25968     1-3 years                    Computers/Technology
#
#                company_size_q21 annual_income_q25 annual_incom€_q25
# index
# 16         1000-9,999 employees       2,000-2,999       1,860-2,789
# 32            250-999 employees               NaN               NaN
# 33               0-49 employees       7,500-9,999       6,975-9,299
# 46               0-49 employees             0-999          0-929,07
# 52            250-999 employees     25,000-29,999     23,250-27,899
# ...                         ...               ...               ...
# 25954         250-999 employees             0-999          0-929,07
# 25959            0-49 employees             0-999          0-929,07
# 25965                       NaN               NaN               NaN
# 25966  10,000 or more employees       3,000-3,999       2,790-3,719
# 25968  10,000 or more employees     15,000-19,999     13,950-18,599
#
# [2301 rows x 11 columns]

# %%
 # pd.crosstab(index = df_analyst['role_q5'], columns = df_analyst['experience_q6'], columns = df_analyst['annual_income_q25'],margins = True)
pd.crosstab(index = df_analyst['annual_incom€_q25'], columns =  df_analyst['experience_q6'],margins = True)
# Out:
# experience_q6      1-3 years  10-20 years  20+ years  3-5 years  5-10 years  \
# annual_incom€_q25
# 0-929,07                 176           10          5         63          18
# 1,860-2,789               27            4          4         11           6
# 116,250-139,499            2            2          2          4           2
# 13,950-18,599             31            4          1         11           7
# 139,500-185,999            2            2          1          1           3
# 18,600-23,249             25            6          0         11          16
# 186,000-232,499            1            0          0          0           2
# 2,790-3,719               29            1          1         10          10
# 23,250-27,899             16            5          3          8           4
# 232,500-278,999            0            1          0          1           0
# 27,900-37,199             21            7          3         12           6
# 279,000-464,999            0            1          0          1           0
# 3,720-4,649               21            2          3         17           4
# 37,200-46,499             25            6          6         15          13
# 4,650-6,974               34            2          0         17           9
# 46,500-55,799             25            7          5         11          11
# 465,000-929,999            0            0          0          0           1
# 55,800-65,099             21           12          4         21          11
# 6,975-9,299               31            7          3         21          10
# 65,100-74,399             19            9          3         18          10
# 74,400-83,699             10            4          2         13           9
# 83,700-92,999              3            5          3          7           4
# 9,300-13,949              61            5          5         20           9
# 93,000-116,249            14           18         12         11          12
# 930-1,859                 68            8          2         26          14
# >930,000                   0            0          0          0           1
# All                      662          128         68        330         192
#
# experience_q6      < 1 years  I have never written code   All
# annual_incom€_q25
# 0-929,07                 209                         48   529
# 1,860-2,789               21                          5    78
# 116,250-139,499            2                          0    14
# 13,950-18,599             17                          5    76
# 139,500-185,999            1                          0    10
# 18,600-23,249             15                          3    76
# 186,000-232,499            1                          0     4
# 2,790-3,719               18                          3    72
# 23,250-27,899             11                          7    54
# 232,500-278,999            0                          1     3
# 27,900-37,199             15                         10    74
# 279,000-464,999            1                          0     3
# 3,720-4,649               19                          2    68
# 37,200-46,499             15                          4    84
# 4,650-6,974               34                         16   112
# 46,500-55,799             10                          5    74
# 465,000-929,999            0                          0     1
# 55,800-65,099              7                          2    78
# 6,975-9,299               16                          7    95
# 65,100-74,399              6                          4    69
# 74,400-83,699              2                          1    41
# 83,700-92,999              3                          0    25
# 9,300-13,949              39                          6   145
# 93,000-116,249             1                          2    70
# 930-1,859                 53                         11   182
# >930,000                   1                          0     2
# All                      517                        142  2039

# %%
# ver relacion entre las categoricas edad, genero y salario
age_gender = pd.crosstab(index = df_as['gender'], columns = df_as['age'], margins = True)
age_gender
# Out:
# age     18-21  22-24  25-29  30-34  35-39  40-44  45-49  50-54  55-59  60-69  \
# gender
# Man      3696   3643   3859   2765   1993   1537   1171    811    509    504
# NB         28     22     17     24     14      5      5      3      4      4
# Woman    1117    963    994    618    455    317    175    136     72     35
# All      4841   4628   4870   3407   2462   1859   1351    950    585    543
#
# age     70+    All
# gender
# Man     110  20598
# NB        4    130
# Woman     8   4890
# All     122  25618

# %%
inc_gender = pd.crosstab(index = df_as['gender'], columns = df_as['annual_incom€_q25'], margins = True).T
inc_gender
# Out:
# gender               Man  NB  Woman    All
# annual_incom€_q25
# 0-929,07            2520  13    775   3308
# 1,860-2,789          461   1    106    568
# 116,250-139,499      337   1     36    374
# 13,950-18,599        504   2     63    569
# 139,500-185,999      334   3     47    384
# 18,600-23,249        500   3     79    582
# 186,000-232,499      160   0     15    175
# 2,790-3,719          314   0     66    380
# 23,250-27,899        383   1     79    463
# 232,500-278,999       61   0      9     70
# 27,900-37,199        625   4    105    734
# 279,000-464,999       81   0      6     87
# 3,720-4,649          386   1     66    453
# 37,200-46,499        586   4     90    680
# 4,650-6,974          579   3    111    693
# 46,500-55,799        592   4     92    688
# 465,000-929,999       29   0      2     31
# 55,800-65,099        462   2     82    546
# 6,975-9,299          440   3    103    546
# 65,100-74,399        391   6     65    462
# 74,400-83,699        339   1     46    386
# 83,700-92,999        301   3     39    343
# 9,300-13,949         809   2    131    942
# 93,000-116,249       611   7     92    710
# 930-1,859            789   3    173    965
# >930,000              48   4      4     56
# All                12642  71   2482  15195

# %%
age_role = pd.crosstab(index = df_as['age'], columns = df_as['role_q5'], margins = True).T
age_role
# Out:
# age                           18-21  22-24  25-29  30-34  35-39  40-44  45-49  \
# role_q5
# Business Analyst                 45    119    200    170    135    107     72
# Currently not employed          140    444    514    264    185    138     97
# DBA/Database Engineer             9     20     17     30     22     21     11
# Data Analyst                    191    419    588    420    280    163    105
# Data Engineer                    41    114    146    104     92     66     45
# Data Scientist                  343    594    907    625    414    317    172
# Developer Relations/Advocacy      7     12     12     14     19      9      6
# Machine Learning Engineer       239    336    377    221    130     82     39
# Other                            52    190    410    418    360    275    250
# Product Manager                   5     15     37     61     52     56     39
# Program/Project Manager          12     32     80    115    134    143    153
# Research Scientist               32     95    260    290    222    209    136
# Software Engineer               228    444    512    372    284    183    170
# Statistician                     15     48     62     49     36     29     26
# Student                        3542   1812    809    288    139     92     54
# All                            4901   4694   4931   3441   2504   1890   1375
#
# age                           50-54  55-59  60-69  70+    All
# role_q5
# Business Analyst                 54     27     35    4    968
# Currently not employed           81     51     53   19   1986
# DBA/Database Engineer            18     10     12    1    171
# Data Analyst                     67     32     28    8   2301
# Data Engineer                    28     19     11    2    668
# Data Scientist                  117     66     50   11   3616
# Developer Relations/Advocacy     13      1      4    2     99
# Machine Learning Engineer        36     20     18    1   1499
# Other                           166    125    115   32   2393
# Product Manager                  34      8     11    1    319
# Program/Project Manager          77     51     46    6    849
# Research Scientist              125     75     76   18   1538
# Software Engineer               109     76     63    8   2449
# Statistician                     11     14     14    9    313
# Student                          28     17     17    6   6804
# All                             964    592    553  128  25973

# %%
age_inc = pd.crosstab(index = df_as['age'], columns = df_as['annual_incom€_q25'], margins = True).T
age_inc
# Out:
# age                18-21  22-24  25-29  30-34  35-39  40-44  45-49  50-54  \
# annual_incom€_q25
# 0-929,07             606    832    765    394    270    164     99     87
# 1,860-2,789           27     81    162     97     81     48     37     27
# 116,250-139,499        4      6     37     62     52     48     66     49
# 13,950-18,599         13     66    141    115    100     59     26     27
# 139,500-185,999        1      7     32     49     76     61     55     38
# 18,600-23,249          9     48    141    127     93     71     46     16
# 186,000-232,499        2      2     10     23     27     18     31     28
# 2,790-3,719           27     68     94     63     62     35     11      7
# 23,250-27,899          6     39    120     97     68     56     45     20
# 232,500-278,999        2      1      4      9     11      9      9     12
# 27,900-37,199         13     37    141    187    102     99     66     49
# 279,000-464,999        2      4      4     10     14     13     15     10
# 3,720-4,649           25    122    118     63     47     29     21     16
# 37,200-46,499          6     45    149    122     97     86     79     44
# 4,650-6,974           30    160    216    123     60     33     31     18
# 46,500-55,799          7     36    130    129    121     95     67     50
# 465,000-929,999        2      0      4      4      5      2      6      5
# 55,800-65,099          7     19     83    124     79     78     77     39
# 6,975-9,299           19    107    168     89     59     43     24     25
# 65,100-74,399          0     19     62    108     81     67     50     26
# 74,400-83,699          1     16     56     84     72     59     31     34
# 83,700-92,999          4     13     37     62     57     47     52     32
# 9,300-13,949          33    164    240    174    114     89     58     38
# 93,000-116,249         7     19     55    124    115    130     91     68
# 930-1,859             74    169    260    180    121     79     43     26
# >930,000               4     12      6      7      8     10      5      0
# All                  931   2092   3235   2626   1992   1528   1141    791
#
# age                55-59  60-69  70+    All
# annual_incom€_q25
# 0-929,07              58     70   24   3369
# 1,860-2,789            8      6    1    575
# 116,250-139,499       27     24    4    379
# 13,950-18,599         15      9    2    573
# 139,500-185,999       27     40    6    392
# 18,600-23,249         24     10    2    587
# 186,000-232,499       19     10    7    177
# 2,790-3,719            7      5    1    380
# 23,250-27,899          7     11    1    470
# 232,500-278,999        8      8    2     75
# 27,900-37,199         19     25    3    741
# 279,000-464,999        9      9    1     91
# 3,720-4,649            8      5    2    456
# 37,200-46,499         26     30    4    688
# 4,650-6,974           12     13    3    699
# 46,500-55,799         33     25    4    697
# 465,000-929,999        4      0    0     32
# 55,800-65,099         27     17    1    551
# 6,975-9,299           10      6    2    552
# 65,100-74,399         31     15    5    464
# 74,400-83,699         19     18    1    391
# 83,700-92,999         20     20    6    350
# 9,300-13,949          21     16    3    950
# 93,000-116,249        56     51    9    725
# 930-1,859              6     10    1    969
# >930,000               3      1    2     58
# All                  504    454   97  15391

# %%
inc_role = pd.crosstab(index = df_as['annual_incom€_q25'], columns = df_as['role_q5'], margins = True).T
inc_role
# Out:
# annual_incom€_q25             0-929,07  1,860-2,789  116,250-139,499  \
# role_q5
# Business Analyst                   150           39               18
# DBA/Database Engineer               23            9                6
# Data Analyst                       529           78               14
# Data Engineer                      109           29               19
# Data Scientist                     731          101              113
# Developer Relations/Advocacy        26            2                1
# Machine Learning Engineer          447           57               33
# Other                              423           67               52
# Product Manager                     28           14               11
# Program/Project Manager            102           25               28
# Research Scientist                 262           53               26
# Software Engineer                  442           92               53
# Statistician                        97            9                5
# All                               3369          575              379
#
# annual_incom€_q25             13,950-18,599  139,500-185,999  18,600-23,249  \
# role_q5
# Business Analyst                         40                7             37
# DBA/Database Engineer                     6                7              6
# Data Analyst                             76               10             76
# Data Engineer                            22               22             29
# Data Scientist                          114              129            110
# Developer Relations/Advocacy              4                1              2
# Machine Learning Engineer                36               29             30
# Other                                    70               66             90
# Product Manager                          11               16              5
# Program/Project Manager                  27               31             30
# Research Scientist                       75               30             77
# Software Engineer                        84               39             85
# Statistician                              8                5             10
# All                                     573              392            587
#
# annual_incom€_q25             186,000-232,499  2,790-3,719  23,250-27,899  \
# role_q5
# Business Analyst                            5           19             29
# DBA/Database Engineer                       2            3              6
# Data Analyst                                4           72             54
# Data Engineer                               4           13             27
# Data Scientist                             53           68            113
# Developer Relations/Advocacy                3            2              3
# Machine Learning Engineer                  16           30             34
# Other                                      30           54             60
# Product Manager                             8            4              6
# Program/Project Manager                    18           16             28
# Research Scientist                         17           34             51
# Software Engineer                          14           58             52
# Statistician                                3            7              7
# All                                       177          380            470
#
# annual_incom€_q25             232,500-278,999  ...  55,800-65,099  \
# role_q5                                        ...
# Business Analyst                            2  ...             31
# DBA/Database Engineer                       0  ...              2
# Data Analyst                                3  ...             78
# Data Engineer                               2  ...             15
# Data Scientist                             15  ...            116
# Developer Relations/Advocacy                1  ...              2
# Machine Learning Engineer                  10  ...             39
# Other                                      13  ...             80
# Product Manager                             5  ...             16
# Program/Project Manager                     5  ...             36
# Research Scientist                         10  ...             54
# Software Engineer                           8  ...             69
# Statistician                                1  ...             13
# All                                        75  ...            551
#
# annual_incom€_q25             6,975-9,299  65,100-74,399  74,400-83,699  \
# role_q5
# Business Analyst                       45             23             27
# DBA/Database Engineer                   4              2              2
# Data Analyst                           95             69             41
# Data Engineer                          19             17             16
# Data Scientist                         86            100            103
# Developer Relations/Advocacy            3              2              3
# Machine Learning Engineer              36             24             26
# Other                                  96             85             58
# Product Manager                        13             15              9
# Program/Project Manager                17             23             23
# Research Scientist                     37             48             30
# Software Engineer                      89             51             49
# Statistician                           12              5              4
# All                                   552            464            391
#
# annual_incom€_q25             83,700-92,999  9,300-13,949  93,000-116,249  \
# role_q5
# Business Analyst                         21            62              38
# DBA/Database Engineer                     6            10               9
# Data Analyst                             25           145              70
# Data Engineer                            16            35              32
# Data Scientist                           85           163             191
# Developer Relations/Advocacy              2             7               2
# Machine Learning Engineer                23            74              43
# Other                                    36           152             119
# Product Manager                           8            11              24
# Program/Project Manager                  36            42              57
# Research Scientist                       36            75              53
# Software Engineer                        53           161              73
# Statistician                              3            13              14
# All                                     350           950             725
#
# annual_incom€_q25             930-1,859  >930,000    All
# role_q5
# Business Analyst                     61         4    885
# DBA/Database Engineer                 5         0    151
# Data Analyst                        182         2   2039
# Data Engineer                        44         2    597
# Data Scientist                      209        14   3240
# Developer Relations/Advocacy          3         2     86
# Machine Learning Engineer            93         4   1327
# Other                                90        11   2204
# Product Manager                       7         2    285
# Program/Project Manager              34         3    784
# Research Scientist                   84         1   1404
# Software Engineer                   132        12   2110
# Statistician                         25         1    279
# All                                 969        58  15391
#
# [14 rows x 27 columns]

# %%
age_gender = pd.DataFrame(df_as.groupby(['gender'])['age'].value_counts())
age_gender
# Out:
#                age
# gender age
# Man    25-29  3859
#        18-21  3696
#        22-24  3643
#        30-34  2765
#        35-39  1993
#        40-44  1537
#        45-49  1171
#        50-54   811
#        55-59   509
#        60-69   504
#        70+     110
# NB     18-21    28
#        30-34    24
#        22-24    22
#        25-29    17
#        35-39    14
#        40-44     5
#        45-49     5
#        55-59     4
#        60-69     4
#        70+       4
#        50-54     3
# Woman  18-21  1117
#        25-29   994
#        22-24   963
#        30-34   618
#        35-39   455
#        40-44   317
#        45-49   175
#        50-54   136
#        55-59    72
#        60-69    35
#        70+       8

# %% [markdown]
# - Frecuencia relativa muestra

# %%
# ver la frecuencia relativa por intervalo de edad
df_age_freq = pd.DataFrame(df_as['age'].value_counts()/len(df_as['age']))*100
 #df_age_frecuencia_rel= (columns : 'age', '%')
round(df_age_freq, 0)
# Out:
#         age
# 25-29  19.0
# 18-21  19.0
# 22-24  18.0
# 30-34  13.0
# 35-39  10.0
# 40-44   7.0
# 45-49   5.0
# 50-54   4.0
# 55-59   2.0
# 60-69   2.0
# 70+     0.0

# %%
df_income_freq= pd.DataFrame(df_as['annual_incom€_q25'].value_counts()/len(df_as['annual_incom€_q25']))*100
round(df_income_freq, 0)
# Out:
#                  annual_incom€_q25
# 0-929,07                      13.0
# 930-1,859                      4.0
# 9,300-13,949                   4.0
# 27,900-37,199                  3.0
# 93,000-116,249                 3.0
# 4,650-6,974                    3.0
# 46,500-55,799                  3.0
# 37,200-46,499                  3.0
# 18,600-23,249                  2.0
# 1,860-2,789                    2.0
# 13,950-18,599                  2.0
# 6,975-9,299                    2.0
# 55,800-65,099                  2.0
# 23,250-27,899                  2.0
# 65,100-74,399                  2.0
# 3,720-4,649                    2.0
# 139,500-185,999                2.0
# 74,400-83,699                  2.0
# 2,790-3,719                    1.0
# 116,250-139,499                1.0
# 83,700-92,999                  1.0
# 186,000-232,499                1.0
# 279,000-464,999                0.0
# 232,500-278,999                0.0
# >930,000                       0.0
# 465,000-929,999                0.0

# %%
df_gender_freq = pd.DataFrame(df_as['gender'].value_counts()/len(df_as['gender']))*100
round(df_gender_freq, 0)
# Out:
#        gender
# Man      79.0
# Woman    19.0
# NB        1.0

# %% [markdown]
#  - Graficos

# %%
# histograma edad
#plt.figure(figsize=(12,8))
#fig = sns.countplot(x = 'age', data = df_as, hue = 'gender')
#fig.set(xlabel = 'Intervalos Edad', ylabel = 'Números de Personas por Intervalo')
#fig.set_title('Distribución Muestra por Edad x Genero')#
#plt.show()

# %%
# countplot para visualizar la distribución de genero por la muestra
plt.figure(figsize=(12,8))
fig = sns.countplot(x = 'gender', data = df_as, hue = 'age')
fig.set(xlabel = 'Gender', ylabel = 'Sample Count')
fig.set_title('Gender Sample x Age')
plt.show()

# %% [markdown]
# - En este gráfico está representado la distribución de edades por género en la muestra. Podemos  ver
# que el género masculino tiene mayor peso con 79% de representación, las mujeres con 19% y los non binarios tienen una representación de 1%.

# %%
plt.figure(figsize = (15,8))
fig = sns.histplot (x = 'annual_incom€_q25', data = df_as, hue = 'gender')
fig.set(xlabel = 'Income', ylabel = 'Annual Income')
fig.set_title('Relation between Income x gender')
plt.xticks(rotation = 60);

# %% [markdown]
#  Podemos ver que existe una brecha salarial entre hombres y mujeres, visto que entre todos los rangos
# salariales considerados, los salarios de los hombres superan los salarios de las mujeres. Información que de igual modo está representada en el gráfico siguiente.

# %%
plt.figure(figsize = (15,8))
fig = sns.countplot (x = 'annual_incom€_q25', data = df_as, hue = 'gender')
fig.set(xlabel = 'Income', ylabel = 'Annual Income')
fig.set_title('Relation between Income x gender')
plt.xticks(rotation = 60);

# %% [markdown]
# ___________________________________________________________________________________________________________________________________

# %%
df_analyst = df_as[df_as['role_q5'] == 'Data Analyst']
df_analyst
# Out:
#         time    age gender                country_q3  \
# index
# 16      1315  50-54    Man                   Belgium
# 32       171  22-24     NB  United States of America
# 33       744  30-34  Woman                     Egypt
# 46      1524  22-24    Man                     China
# 52       866  40-44    Man              South Africa
# ...      ...    ...    ...                       ...
# 25954    474  25-29    Man                     India
# 25959  96354  18-21    Man                     India
# 25965  40250  18-21    Man                     India
# 25966    323  30-34    Man                     India
# 25968   1756  30-34    Man                     Egypt
#
#                                             education_q4       role_q5  \
# index
# 16                                     Bachelor’s degree  Data Analyst
# 32     Some college/university study without earning ...  Data Analyst
# 33                                     Bachelor’s degree  Data Analyst
# 46     Some college/university study without earning ...  Data Analyst
# 52                                       Master’s degree  Data Analyst
# ...                                                  ...           ...
# 25954                             Professional doctorate  Data Analyst
# 25959                                  Bachelor’s degree  Data Analyst
# 25965                                    Master’s degree  Data Analyst
# 25966                                  Bachelor’s degree  Data Analyst
# 25968                                  Bachelor’s degree  Data Analyst
#
#       experience_q6                              sector_q20  \
# index
# 16        20+ years                           Energy/Mining
# 32        < 1 years               Manufacturing/Fabrication
# 33        3-5 years                      Non-profit/Service
# 46        < 1 years                    Computers/Technology
# 52        1-3 years               Manufacturing/Fabrication
# ...             ...                                     ...
# 25954     < 1 years  Online Service/Internet-based Services
# 25959     1-3 years                     Academics/Education
# 25965     1-3 years                                     NaN
# 25966     1-3 years               Manufacturing/Fabrication
# 25968     1-3 years                    Computers/Technology
#
#                company_size_q21 annual_income_q25 annual_incom€_q25
# index
# 16         1000-9,999 employees       2,000-2,999       1,860-2,789
# 32            250-999 employees               NaN               NaN
# 33               0-49 employees       7,500-9,999       6,975-9,299
# 46               0-49 employees             0-999          0-929,07
# 52            250-999 employees     25,000-29,999     23,250-27,899
# ...                         ...               ...               ...
# 25954         250-999 employees             0-999          0-929,07
# 25959            0-49 employees             0-999          0-929,07
# 25965                       NaN               NaN               NaN
# 25966  10,000 or more employees       3,000-3,999       2,790-3,719
# 25968  10,000 or more employees     15,000-19,999     13,950-18,599
#
# [2301 rows x 11 columns]

# %%
plt.figure(figsize =(10,8))
sns.countplot(x=df_analyst['role_q5'],data = df_analyst , hue='gender')
plt.xticks(rotation= 75)
plt.show()
