# %%
import pandas as pd
import numpy as np

# %%
#Creamos un dataframe con los datos del archivo 'data_remaning_kaggle.csv' .
df_remaining=pd.read_csv('../files/data_remaning_kaggle.csv')
df_remaining.head()
# Out:
#    Unnamed: 0  index                                         Q18_Part_1  \
# 0           0      0  General purpose image/video tools (PIL, cv2, s...
# 1           1      1                                                NaN
# 2           2      2                                                NaN
# 3           3      3  General purpose image/video tools (PIL, cv2, s...
# 4           4      4                                                NaN
#
#                                           Q18_Part_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Image segmentation methods (U-Net, Mask R-CNN,...
# 4                                                NaN
#
#                                           Q18_Part_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Object detection methods (YOLOv3, RetinaNet, etc)
# 4                                                NaN
#
#                                           Q18_Part_4 Q18_Part_5 Q18_Part_6  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  Image classification and other general purpose...        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Q18_OTHER                                         Q19_Part_1  ...  \
# 0       NaN  Word embeddings/vectors (GLoVe, fastText, word...  ...
# 1       NaN                                                NaN  ...
# 2       NaN                                                NaN  ...
# 3       NaN                                                NaN  ...
# 4       NaN                                                NaN  ...
#
#   Q38_B_Part_3 Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6 Q38_B_Part_7  \
# 0          NaN          NaN            NaN          NaN          NaN
# 1          NaN          NaN            NaN          NaN          NaN
# 2          NaN          NaN   TensorBoard           NaN          NaN
# 3          NaN          NaN            NaN          NaN          NaN
# 4          NaN          NaN            NaN          NaN          NaN
#
#   Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11 Q38_B_OTHER
# 0          NaN          NaN           NaN           NaN         NaN
# 1          NaN          NaN           NaN          None         NaN
# 2          NaN          NaN           NaN           NaN         NaN
# 3          NaN          NaN           NaN          None         NaN
# 4          NaN          NaN           NaN           NaN         NaN
#
# [5 rows x 214 columns]

# %%
df_remaining.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3',
#        'Q18_Part_4', 'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=214)

# %% [markdown]
# Información sobre los DataFrames y sus relaciones:

# %%
df_txt.columns
# Out:
# Index(['index', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11', 'Q13', 'Q15', 'Q20',
#        'Q21', 'Q22', 'Q23', 'Q25', 'Q26', 'Q33', 'Q35', 'Q41', 'Q7', 'Q9',
#        'Q12', 'Q14', 'Q16', 'Q17', 'Q24', 'Q32', 'Q34'],
#       dtype='object')

# %%
df_csv.columns
# Out:
# Index(['index', 'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4',
#        'Q10_Part_5', 'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9',
#        'Q10_Part_10', 'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13',
#        'Q10_Part_14', 'Q10_Part_15', 'Q10_Part_16', 'Q10_OTHER'],
#       dtype='object')

# %%
#pendiente código: df_xml.columns

# %% [markdown]
# Con respecto a las relaciones entre dataframes. En este caso, qué columna(s) tienen en común.

# %%
np.intersect1d(df_remaining.columns, df_txt.columns)
# Out:
# array(['index'], dtype=object)

# %%
np.intersect1d(df_remaining.columns, df_csv.columns)
# Out:
# array(['index'], dtype=object)

# %%
np.intersect1d(df_csv.columns, df_txt.columns)
# Out:
# array(['index'], dtype=object)

# %% [markdown]
#         Vemos que la única columna que tienen en común los archivos es la columna 'index'.

# %% [markdown]
# La columna ''Unnamed: 0' no nos interesa, ya que duplica la información que ofrece index (que, como hemos visto, es la única columna que tienen en común todos nuestros DataFrames):

# %%
df_remaining=df_remaining.drop(['Unnamed: 0'],axis=1)
df_remaining.columns
# Out:
# Index(['index', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3', 'Q18_Part_4',
#        'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1', 'Q19_Part_2',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=213)

# %%
#Creamos un dataframe con los datos del archivo 'data_txt_clean.txt' .
df_txt=pd.read_csv('../files/data_txt_clean.txt',delimiter=';')
df_txt.head()
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
# 3      3     Mexico    Doctoral degree       Research Scientist   20+ years
# 4      4      India    Doctoral degree                    Other   < 1 years
#
#        Q8                                                Q11  \
# 0  Python                                           A laptop
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 2  Python                                           A laptop
# 3  Python  A cloud computing platform (AWS, Azure, GCP, h...
# 4  Python  A cloud computing platform (AWS, Azure, GCP, h...
#
#                   Q13                                    Q15  \
# 0           2-5 times                             5-10 years
# 1               Never                               < 1 year
# 2               Never  I do not use machine learning methods
# 3  More than 25 times                             5-10 years
# 4               Never                            10-20 years
#
#                          Q20  ...  \
# 0  Manufacturing/Fabrication  ...
# 1  Manufacturing/Fabrication  ...
# 2        Academics/Education  ...
# 3        Academics/Education  ...
# 4        Academics/Education  ...
#
#                                                  Q41                  Q7  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
# 2  Basic statistical software (Microsoft Excel, G...   Python, C++, Java
# 3  Local development environments (RStudio, Jupyt...              Python
# 4  Local development environments (RStudio, Jupyt...   Python, C, MATLAB
#
#                                  Q9                 Q12  \
# 0                       Vim / Emacs  Google Cloud TPUs
# 1        Notepad++,Jupyter Notebook                None
# 2  PyCharm ,Jupyter Notebook, Other               Other
# 3           Spyder,Jupyter Notebook        NVIDIA GPUs
# 4   Spyder,MATLAB ,Jupyter Notebook                None
#
#                                                  Q14  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
# 2                                        Matplotlib
# 3                                        Matplotlib
# 4             Matplotlib ,Seaborn ,Ggplot / ggplot2
#
#                                  Q16  \
# 0  Scikit-learn , TensorFlow ,Caret
# 1                      Scikit-learn
# 2                                NaN
# 3  Scikit-learn , TensorFlow ,Keras
# 4   Scikit-learn ,PyTorch ,LightGBM
#
#                                                  Q17  \
# 0  Linear or Logistic Regression, Decision Trees ...
# 1  Linear or Logistic Regression, Decision Trees ...
# 2                                                NaN
# 3   Dense Neural Networks (MLPs, etc), Convolutio...
# 4  Linear or Logistic Regression, Decision Trees ...
#
#                                                  Q24               Q32  \
# 0   None of these activities are an important par...       PostgreSQL
# 1   Build and/or run the data infrastructure that...               NaN
# 2   None of these activities are an important par...  MySQL , MongoDB
# 3   Do research that advances the state of the ar...               NaN
# 4  Analyze and understand data to influence produ...              None
#
#                    Q34
# 0                 None
# 1                  NaN
# 2                 None
# 3                  NaN
# 4   Microsoft Power BI
#
# [5 rows x 27 columns]

# %%
#Creamos un dataframe con los datos del archivo 'data_xml_clean.xml' .
df_xml=pd.read_xml('../files/data_xml_clean.xml')
df_xml.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [7], line 2
#       1 #Creamos un dataframe con los datos del archivo 'data_xml_clean.xml' .
# ----> 2 df_xml=pd.read_xml('../files/data_xml_clean.xml')
#       3 df_xml.head()
#
# File c:\Users\PcCom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\PcCom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\xml.py:1088, in read_xml(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options)
#     838 @deprecate_nonkeyword_arguments(version=None, allowed_args=["path_or_buffer"])
#     839 @doc(
#     840     storage_options=_shared_docs["storage_options"],
#    (...)
#     859     storage_options: StorageOptions = None,
#     860 ) -> DataFrame:
#     861     r"""
#     862     Read XML document into a ``DataFrame`` object.
#     863
#    (...)
#    1085     2  triangle      180    3.0
#    1086     """
# -> 1088     return _parse(
#    1089         path_or_buffer=path_or_buffer,
#    1090         xpath=xpath,
#    1091         namespaces=namespaces,
#    1092         elems_only=elems_only,
#    1093         attrs_only=attrs_only,
#    1094         names=names,
#    1095         dtype=dtype,
#    1096         converters=converters,
#    1097         parse_dates=parse_dates,
#    1098         encoding=encoding,
#    1099         parser=parser,
#    1100         stylesheet=stylesheet,
#    1101         iterparse=iterparse,
#    1102         compression=compression,
#    1103         storage_options=storage_options,
#    1104     )
#
# File c:\Users\PcCom\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\xml.py:805, in _parse(path_or_buffer, xpath, namespaces, elems_only, attrs_only, names, dtype, converters, parse_dates, encoding, parser, stylesheet, iterparse, compression, storage_options, **kwargs)
#     788         p = _LxmlFrameParser(
#     789             path_or_buffer,
#     790             xpath,
#    (...)
#     802             storage_options,
#     803         )
#     804     else:
# --> 805         raise ImportError("lxml not found, please install or use the etree parser.")
#     807 elif parser == "etree":
#     808     p = _EtreeFrameParser(
#     809         path_or_buffer,
#     810         xpath,
#    (...)
#     822         storage_options,
#     823     )
#
# ImportError: lxml not found, please install or use the etree parser.

# %%
#Creamos un dataframe con los datos del archivo 'exported_db_data.csv' .
df_csv=pd.read_csv('../files/exported_db_data.csv')
df_csv.head()
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10  \
# 0        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN
#
#             Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15  \
# 0                   NaN         NaN         NaN         NaN         NaN
# 1                   NaN         NaN         NaN         NaN         NaN
# 2                   NaN         NaN         NaN         NaN         NaN
# 3                   NaN         NaN         NaN         NaN         NaN
# 4  Google Cloud Datalab         NaN         NaN         NaN         NaN
#
#   Q10_Part_16 Q10_OTHER
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN

# %%
print(df_csv)
# Out:
#        index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4  \
# 0          0                NaN  Colab Notebooks        NaN        NaN
# 1          1   Kaggle Notebooks  Colab Notebooks        NaN        NaN
# 2          2   Kaggle Notebooks              NaN        NaN        NaN
# 3          3                NaN  Colab Notebooks        NaN        NaN
# 4          4                NaN              NaN        NaN        NaN
# ...      ...                ...              ...        ...        ...
# 25968  25968                NaN  Colab Notebooks        NaN        NaN
# 25969  25969                NaN              NaN        NaN        NaN
# 25970  25970                NaN              NaN        NaN        NaN
# 25971  25971                NaN              NaN        NaN        NaN
# 25972  25972                NaN              NaN        NaN        NaN
#
#       Q10_Part_5 Q10_Part_6 Q10_Part_7                           Q10_Part_8  \
# 0            NaN        NaN        NaN                                  NaN
# 1            NaN        NaN        NaN                                  NaN
# 2            NaN        NaN        NaN                                  NaN
# 3            NaN        NaN        NaN                                  NaN
# 4            NaN        NaN        NaN                                  NaN
# ...          ...        ...        ...                                  ...
# 25968        NaN        NaN        NaN   Amazon Sagemaker Studio Notebooks
# 25969        NaN        NaN        NaN                                  NaN
# 25970        NaN        NaN        NaN                                  NaN
# 25971        NaN        NaN        NaN                                  NaN
# 25972        NaN        NaN        NaN                                  NaN
#
#                    Q10_Part_9 Q10_Part_10           Q10_Part_11  \
# 0                         NaN         NaN                   NaN
# 1                         NaN         NaN                   NaN
# 2                         NaN         NaN                   NaN
# 3                         NaN         NaN                   NaN
# 4                         NaN         NaN  Google Cloud Datalab
# ...                       ...         ...                   ...
# 25968   Amazon EMR Notebooks          NaN                   NaN
# 25969                     NaN         NaN                   NaN
# 25970                     NaN         NaN                   NaN
# 25971                     NaN         NaN                   NaN
# 25972                     NaN         NaN                   NaN
#
#                                 Q10_Part_12 Q10_Part_13 Q10_Part_14  \
# 0                                       NaN         NaN         NaN
# 1                                       NaN         NaN         NaN
# 2                                       NaN         NaN         NaN
# 3                                       NaN         NaN         NaN
# 4                                       NaN         NaN         NaN
# ...                                     ...         ...         ...
# 25968   Databricks Collaborative Notebooks          NaN         NaN
# 25969                                   NaN         NaN         NaN
# 25970                                   NaN         NaN         NaN
# 25971                                   NaN         NaN         NaN
# 25972                                   NaN         NaN         NaN
#
#       Q10_Part_15 Q10_Part_16 Q10_OTHER
# 0             NaN         NaN       NaN
# 1             NaN         NaN       NaN
# 2             NaN         NaN       NaN
# 3             NaN         NaN       NaN
# 4             NaN         NaN       NaN
# ...           ...         ...       ...
# 25968         NaN         NaN       NaN
# 25969         NaN        None       NaN
# 25970         NaN         NaN       NaN
# 25971         NaN        None       NaN
# 25972         NaN         NaN       NaN
#
# [25973 rows x 18 columns]

# %% [markdown]
# Primero, vamos a ver los índices que tienen los DataFrames de cara a valorar qué columna será el index que nos interesa.

# %%
df_

# %%
df_concat=pd.concat([df1,df3],axis=1,ignore_index=False)
df_concat.head()
