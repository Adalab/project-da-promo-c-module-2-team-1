# %% [markdown]
# ## Limpieza del CSV:

# %%
#librerías para el manejo de los datos
import pandas as pd
import numpy as np

#librerías para la visualización de los datos
import matplotlib.pyplot as plt
import seaborn as sns

#librerías para los análisis estadísticos
from scipy.stats import skew

import pycountry_convert as pc

pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %% [markdown]
# Ejecutar solo si no se ha instalado antes el pycountry:

# %%
#!pip install pycountry-convert

# %% [markdown]
# ### 1. Invocación del DF y depuración de las variables:

# %%
df = pd.read_csv('../files/df_a_usar_2.csv', index_col=0)
df.head()
# Out:
#    index  time    age gender country_q3       education_q4  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
# 2      2   924  22-24    Man   Pakistan    Master’s degree
# 3      3   575  45-49    Man     Mexico    Doctoral degree
# 4      4   781  45-49    Man      India    Doctoral degree
#
#                    role_q5 experience_q6      Q8  \
# 0                    Other    5-10 years  Python
# 1  Program/Project Manager     20+ years  Python
# 2        Software Engineer     1-3 years  Python
# 3       Research Scientist     20+ years  Python
# 4                    Other     < 1 years  Python
#
#                                                  Q11                 Q13  \
# 0                                           A laptop           2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...               Never
# 2                                           A laptop               Never
# ...

# %%
df.shape
# Out:
# (25973, 242)

# %% [markdown]
# Seleccionamos las columnas que no nos interesan:

# %%
df2=df[['age', 'gender', 'country_q3', 'education_q4', 'role_q5', 
        'experience_q6','Q7','sector_q20', 'company_size_q21','anual_income_q25']]

# %%
#comprobamos el cambio:
df2.columns
# Out:
# Index(['age', 'gender', 'country_q3', 'education_q4', 'role_q5',
#        'experience_q6', 'Q7', 'sector_q20', 'company_size_q21',
#        'anual_income_q25'],
#       dtype='object')

# %%
df2.shape
# Out:
# (25973, 10)

# %% [markdown]
# #### Edad -- no hay que tocarla:

# %%
df2['age'].value_counts()
# Out:
# 25-29    4931
# 18-21    4901
# 22-24    4694
# 30-34    3441
# 35-39    2504
# 40-44    1890
# 45-49    1375
# 50-54     964
# 55-59     592
# 60-69     553
# 70+       128
# Name: age, dtype: int64

# %% [markdown]
# #### Pais:

# %%
#Vamos a crear una columna nueva para establecer a que continente pertenece cada pais de procedencia.
#Para ello debemos intalarnos la libreria 'pycountry-convert'
#pip install pycountry-convert
#Y la importamos.

def country_to_continent(country_name):
    try:
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
        return country_continent_name
    except:
        return country_name

# %%
#Vamos a crear una columna nueva para establecer a que continente pertenece cada pais de procedencia.
#Para ello debemos intalarnos la libreria 'pycountry-convert'
#pip install pycountry-convert
#Y la importamos.

def country_to_continent(country_name):
    try:
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
        return country_continent_name
    except:
        return country_name

index_iran=df2.index[df2['country_q3']=='Iran, Islamic Republic of...']
print('Numero de indices obtenidos en Irán:',len(index_iran))

#Procedemos a hacer lo mismo con Hong Kong.
index_hk=df2.index[df2['country_q3']=='Hong Kong (S.A.R.)']
print('Numero de indices obtenidos en Hong Kong:',len(index_hk))


for i in index_iran:
    df2['country_q3'].iloc[i] = "Iran"

for i in index_hk:
    df2['country_q3'].iloc[i] = 'Hong Kong'
    
#Aplicamos la funcion ahora que hemos sustituido Iran.
df2['continent']=df2['country_q3'].apply(country_to_continent)
# Out:
# Numero de indices obtenidos en Irán: 195
# Numero de indices obtenidos en Hong Kong: 79
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /var/folders/t6/q3b9mm2s4gq82rvww5q2z2tr0000gn/T/ipykernel_33043/1214506350.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['continent']=df2['country_q3'].apply(country_to_continent)

# %%
for i in index_iran:
    df2['country_q3'].iloc[i] = "Iran"

for i in index_hk:
    df2['country_q3'].iloc[i] = 'Hong Kong'

# %%
#Aplicamos la funcion ahora que hemos sustituido Iran.
df2['continent']=df2['country_q3'].apply(country_to_continent)
# Out:
# /var/folders/t6/q3b9mm2s4gq82rvww5q2z2tr0000gn/T/ipykernel_33043/86955938.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['continent']=df2['country_q3'].apply(country_to_continent)

# %%
#comprobamos la aplicación de la función:
df2['continent'].unique()
# Out:
# array(['Asia', 'North America', 'Europe', 'Oceania', 'Africa',
#        'South America', 'Other', 'I do not wish to disclose my location'],
#       dtype=object)

# %% [markdown]
# #### *Género:

# %%
df2['gender_def'] = df2['gender'].replace({'Man': 'Man', 'Woman': 'Woman', 'Prefer to self-describe': 'NB', 'Nonbinary': 'NB', 'Prefer not to say': np.nan})
# Out:
# /var/folders/t6/q3b9mm2s4gq82rvww5q2z2tr0000gn/T/ipykernel_33043/1240910373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['gender_def'] = df2['gender'].replace({'Man': 'Man', 'Woman': 'Woman', 'Prefer to self-describe': 'NB', 'Nonbinary': 'NB', 'Prefer not to say': np.nan})

# %%
df2['gender_def'].value_counts()
# Out:
# Man      20598
# Woman     4890
# NB         130
# Name: gender_def, dtype: int64

# %%
df2['gender_def'].isnull().sum()
# Out:
# 355

# %%
#lo he intentado con dropna pero no nos ha funcionado. 
#opto, por ende, quedarnos simplemente con los casos no-nulos:
#https://stackoverflow.com/a/13413845

df2 = df2[df2['gender_def'].notna()]

# %%
df2['gender_def'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Educación -- Limpia de por sí.

# %%
df2['education_q4'].value_counts()
# Out:
# Master’s degree                                                      9981
# Bachelor’s degree                                                    9816
# Doctoral degree                                                      2751
# Some college/university study without earning a bachelor’s degree    1713
# I prefer not to answer                                                591
# No formal education past high school                                  412
# Professional doctorate                                                354
# Name: education_q4, dtype: int64

# %% [markdown]
# #### Puesto:

# %%
def roles_rar (col):
    
    data = ['Data Scientist','Data Engineer', 'Business Analyst', 'Statistician']
    supervising_roles = ['Program/Project Manager', 'Product Manager',]
    soft_eng = ["Software Engineer", "DBA/Database Engineer"]
    relatios = ["Developer Relations/Advocacy"]
    nulos = ["Currently not employed", "Other"]
    student = ['Student']

    if col in data:
        return 'Data-related role'
    elif col in supervising_roles:
        return 'Supervising role'
    elif col in soft_eng:
        return 'Sofware-related role'
    elif col in relatios:
        return "Developer Relations/Advocacy"
    elif col in student:
        return 'Student'
    elif col in nulos:
        return np.nan

# %%
df2['role_q5_def'] = df2['role_q5'].apply(roles_rar)

# %%
df2['role_q5_def'].value_counts()
# Out:
# Student                         6703
# Data-related role               5500
# Sofware-related role            2581
# Supervising role                1150
# Developer Relations/Advocacy      97
# Name: role_q5_def, dtype: int64

# %% [markdown]
# #### Experiencia -- Limpia de por si:

# %%
df2['experience_q6'].value_counts()
# Out:
# 1-3 years                    7784
# < 1 years                    5809
# 3-5 years                    4009
# 5-10 years                   3043
# 10-20 years                  2131
# 20+ years                    1820
# I have never written code    1022
# Name: experience_q6, dtype: int64

# %% [markdown]
# #### *Lenguaje -- Sonia

# %%
df2.rename(columns={"Q7": "language_q7"}, inplace=True)

# %% [markdown]
# #### ?Sector:

# %% [markdown]
# #### Tamaño de la empresa:

# %%
#limpia de por si, pero quitamos los nulos:
df2['company_size_q21'].isnull().sum()
# Out:
# 9580

# %%
#nos quedamos con los que no son nulos:
df2 = df2[df2['company_size_q21'].notna()]

# %%
df2.shape
# Out:
# (16038, 13)

# %%
df2['company_size_q21'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Salario:

# %%
# quitamos '$' 
df2['anual_income_q25'] = df2['anual_income_q25'].replace('$0-999','0-999')
df2['anual_income_q25'] = df2['anual_income_q25'].replace('>$1,000,000','>1,000,000')

# %%
list_income = list(df2['anual_income_q25'].unique())
list_income
# Out:
# ['25,000-29,999',
#  '60,000-69,999',
#  '0-999',
#  '30,000-39,999',
#  '15,000-19,999',
#  '70,000-79,999',
#  '2,000-2,999',
#  '10,000-14,999',
#  '5,000-7,499',
#  '20,000-24,999',
#  '1,000-1,999',
#  '100,000-124,999',
#  '7,500-9,999',
#  nan,
#  '4,000-4,999',
#  '40,000-49,999',
#  '50,000-59,999',
#  '3,000-3,999',
#  '300,000-499,999',
#  '200,000-249,999',
#  '125,000-149,999',
#  '250,000-299,999',
#  '80,000-89,999',
#  '90,000-99,999',
#  '150,000-199,999',
#  '>1,000,000',
#  '$500,000-999,999']

# %%
# lista con los valores del los rangos [annual_income_q25] convertidos a euros:
list_income_new = ['23,250-27,899', '55,800-65,099', '0-929,07', '27,900-37,199', np.nan,
                   '13,950-18,599', '65,100-74,399', '1,860-2,789', '9,300-13,949',
                   '4,650-6,974', '18,600-23,249', '930-1,859', '93,000-116,249',
                   '6,975-9,299', '3,720-4,649', '37,200-46,499', '46,500-55,799',
                   '2,790-3,719', '279,000-464,999', '186,000-232,499',
                   '116,250-139,499', '232,500-278,999', '74,400-83,699', '83,700-92,999', '139,500-185,999', '>930,000',
                   '465,000-929,999']

# %%
# creamos la nueva columna:
df2['annual_incom€_q25'] = df2['anual_income_q25'].replace(list_income, list_income_new)

# %%
df2['annual_incom€_q25'].unique()
# Out:
# array(['23,250-27,899', '55,800-65,099', '0-929,07', '27,900-37,199', nan,
#        '13,950-18,599', '65,100-74,399', '1,860-2,789', '9,300-13,949',
#        '4,650-6,974', '18,600-23,249', '930-1,859', '93,000-116,249',
#        '6,975-9,299', '3,720-4,649', '37,200-46,499', '46,500-55,799',
#        '2,790-3,719', '279,000-464,999', '186,000-232,499',
#        '116,250-139,499', '232,500-278,999', '74,400-83,699',
#        '83,700-92,999', '139,500-185,999', '>930,000', '465,000-929,999'],
#       dtype=object)

# %% [markdown]
# ## Guardamos en un csv:

# %%
df2.to_csv('../files/df_depurado.csv')

# %% [markdown]
# ## Filtramos por europa:

# %%
europa = df2[df2['continent'] == 'Europe']
europa.head()
# Out:
#       age gender country_q3            education_q4  \
# 15  35-39    Man     Greece         Doctoral degree
# 16  50-54    Man    Belgium       Bachelor’s degree
# 25  25-29  Woman     Poland         Master’s degree
# 41  25-29    Man      Italy         Master’s degree
# 57  35-39  Woman     Russia  I prefer not to answer
#
#                       role_q5 experience_q6             language_q7  \
# 15         Research Scientist   10-20 years  Python, C, C++, MATLAB
# 16               Data Analyst     20+ years             Python, SQL
# 25  Machine Learning Engineer     3-5 years             Python, C++
# 41                      Other     1-3 years          Python, MATLAB
# 57             Data Scientist     1-3 years               Python, R
#
#               sector_q20      company_size_q21 anual_income_q25 continent  \
# 15   Academics/Education      50-249 employees    10,000-14,999    Europe
# 16         Energy/Mining  1000-9,999 employees      2,000-2,999    Europe
# ...

# %% [markdown]
# ## EU - Guardamos en un csv:

# %%
europa.to_csv('../files/df_eu_depurado.csv')
