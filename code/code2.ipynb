# %% [markdown]
# ### Exploración y depuración de los DataFrames.

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import lxml
import matplotlib as plt

# %%
pd.options.display.max_columns=None

# %% [markdown]
# # 1. Abrimos los DataFrames:
# - exported_db_data.csv
# - data_remaning_kaggle.csv
# - data_txt_clean.txt
# - exported_db_data.csv --> solo lo unificaremos, no lo vamos a usar para contestar nuestras preguntas de investigación.

# %% [markdown]
# ### - data_remaning_kaggle.csv

# %%
#Creamos un dataframe con los datos del archivo 'data_remaning_kaggle.csv' .
df_remaining=pd.read_csv('../files/data_remaning_kaggle.csv')
df_remaining.head()
# Out:
#    Unnamed: 0  index                                         Q18_Part_1  \
# 0           0      0  General purpose image/video tools (PIL, cv2, s...
# 1           1      1                                                NaN
# 2           2      2                                                NaN
# 3           3      3  General purpose image/video tools (PIL, cv2, s...
# 4           4      4                                                NaN
#
#                                           Q18_Part_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Image segmentation methods (U-Net, Mask R-CNN,...
# 4                                                NaN
#
#                                           Q18_Part_3  \
# 0                                                NaN
# 1                                                NaN
# ...

# %% [markdown]
# * ### ARCHIVO TXT:

# %%
df_txt = pd.read_csv('../files/data_txt_clean.txt', sep=';')
df_txt.head(3)
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
# 2      2   Pakistan    Master’s degree        Software Engineer   1-3 years
#
#        Q8                                                Q11        Q13  \
# 0  Python                                           A laptop  2-5 times
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...      Never
# 2  Python                                           A laptop      Never
#
#                                      Q15                        Q20  \
# 0                             5-10 years  Manufacturing/Fabrication
# 1                               < 1 year  Manufacturing/Fabrication
# 2  I do not use machine learning methods        Academics/Education
#
#                     Q21  Q22  \
# 0      50-249 employees  3-4
# 1  1000-9,999 employees  1-2
# ...

# %% [markdown]
# * ### ARCHIVO XML

# %% [markdown]
# * Importamos LXML para leer el archivo XML.

# %%
# !pip install lxml

# %%
df_xml = pd.read_xml('../files/data_xml_clean.xml')
df_xml.head(3)
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man
# 1        1      1   784  50-54    Man
# 2        2      2   924  22-24    Man

# %%
#confirmamos que nos lo ha 'trasladado' como un DataFrame de Pandas.
type(df_xml)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# * ### exported_db_data.csv

# %% [markdown]
# Este archivo lo vamos a unificar pero no vamos a utilizar la información que contiene.

# %%
df_exported = pd.read_csv('../files/exported_db_data.csv')
df_exported.head(3)
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10 Q10_Part_11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
#
#   Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15 Q10_Part_16 Q10_OTHER
# 0         NaN         NaN         NaN         NaN         NaN       NaN
# 1         NaN         NaN         NaN         NaN         NaN       NaN
# 2         NaN         NaN         NaN         NaN         NaN       NaN

# %% [markdown]
# ## Información sobre los DataFrames y sus relaciones:

# %% [markdown]
# Con respecto a las relaciones entre dataframes. En este caso, qué columna(s) tienen en común.

# %%
np.intersect1d(df_remaining.columns, df_txt.columns)
# Out:
# array(['index'], dtype=object)

# %%
np.intersect1d(df_exported.columns, df_xml.columns)
# Out:
# array(['index'], dtype=object)

# %%
np.intersect1d(df_remaining.columns, df_xml.columns)
# Out:
# array(['index'], dtype=object)

# %%
np.intersect1d(df_xml.columns, df_txt.columns)
# Out:
# array(['index'], dtype=object)

# %% [markdown]
#         Vemos que la única columna que tienen en común los archivos es la columna 'index'.

# %% [markdown]
# La columna ''Unnamed: 0' no nos interesa, ya que duplica la información que ofrece index (que, como hemos visto, es la única columna que tienen en común todos nuestros DataFrames):

# %%
df_remaining=df_remaining.drop(['Unnamed: 0'],axis=1)
df_remaining.columns
# Out:
# Index(['index', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3', 'Q18_Part_4',
#        'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1', 'Q19_Part_2',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=213)

# %% [markdown]
# ## Unimos las BBDD:
#     - Concat:
#         - En caso de que las columnas no se llamen igual o contengan tipode de datos diferentes, rellena con NaNs las celdas.
#     - Merge:
#         - La forma de añadir dos columnas a un dataframe. por defecto se hace con ...
#     - Merge cross:
#         -

# %%
mega_data_frame = pd.concat([df_xml, df_txt, df_exported, df_remaining], axis=1)
mega_data_frame
# Out:
#        level_0  index  time    age gender  index                        Q3  \
# 0            0      0   910  50-54    Man      0                     India
# 1            1      1   784  50-54    Man      1                 Indonesia
# 2            2      2   924  22-24    Man      2                  Pakistan
# 3            3      3   575  45-49    Man      3                    Mexico
# 4            4      4   781  45-49    Man      4                     India
# ...        ...    ...   ...    ...    ...    ...                       ...
# 25968    25968  25968  1756  30-34    Man  25968                     Egypt
# 25969    25969  25969   253  22-24    Man  25969                     China
# 25970    25970  25970   494  50-54    Man  25970                    Sweden
# 25971    25971  25971   277  45-49    Man  25971  United States of America
# 25972    25972  25972   255  18-21    Man  25972                     India
#
# ...

# %%
mega_data_frame.columns
# Out:
# Index(['level_0', 'index', 'time', 'age', 'gender', 'index', 'Q3', 'Q4', 'Q5',
#        'Q6',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=263)

# %%
df_a_usar = pd.concat([df_xml, df_txt, df_remaining], axis=1)

# %%
df_a_usar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Columns: 245 entries, level_0 to Q38_B_OTHER
# dtypes: float64(8), int64(5), object(232)
# memory usage: 48.5+ MB

# %%
#para evitar la creación de la columna 'Unnamed_0' 
df_a_usar.to_csv('df_a_usar.csv', index=False)

# %%
#¡voilá! no se ha creado la columna 'Unnamed_0'
df = pd.read_csv('../files/df_a_usar.csv')
df.head(3)
# Out:
#    level_0  index  time    age gender  index.1         Q3                 Q4  \
# 0        0      0   910  50-54    Man        0      India  Bachelor’s degree
# 1        1      1   784  50-54    Man        1  Indonesia    Master’s degree
# 2        2      2   924  22-24    Man        2   Pakistan    Master’s degree
#
#                         Q5          Q6      Q8  \
# 0                    Other  5-10 years  Python
# 1  Program/Project Manager   20+ years  Python
# 2        Software Engineer   1-3 years  Python
#
#                                                  Q11        Q13  \
# 0                                           A laptop  2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never
# 2                                           A laptop      Never
#
#                                      Q15                        Q20  \
# 0                             5-10 years  Manufacturing/Fabrication
# ...

# %% [markdown]
# ### Limpieza y exploración de la BBDD.

# %%
#Hemos comprobado mediante el método sum si las columnas exploradas tenían el mismo número de casos, porque asumimos que son índices:
df['level_0'].sum() == df['index'].sum() == df['index.1'].sum()
# Out:
# True

# %%
#No hay columnas con información duplicada.
df.duplicated().sum()
# Out:
# 0

# %%
#extraemos los principales métodos estadísticos de las columnas numéricas.
df.describe()
# Out:
#             level_0         index          time       index.1    Unnamed: 0  \
# count  25973.000000  25973.000000  2.597300e+04  25973.000000  25973.000000
# mean   12986.000000  12986.000000  1.105466e+04  12986.000000  12986.000000
# std     7497.903607   7497.903607  1.014716e+05   7497.903607   7497.903607
# min        0.000000      0.000000  1.200000e+02      0.000000      0.000000
# 25%     6493.000000   6493.000000  4.430000e+02   6493.000000   6493.000000
# 50%    12986.000000  12986.000000  6.560000e+02  12986.000000  12986.000000
# 75%    19479.000000  19479.000000  1.038000e+03  19479.000000  19479.000000
# max    25972.000000  25972.000000  2.488653e+06  25972.000000  25972.000000
#
#             index.2  Q30_B_Part_1  Q30_B_Part_2  Q30_B_Part_3  Q30_B_Part_4  \
# count  25973.000000           0.0           0.0           0.0           0.0
# mean   12986.000000           NaN           NaN           NaN           NaN
# ...

# %% [markdown]
# * Borrado de columnas:

# %% [markdown]
# Observando los principales métodos estadísticos en las columnas level_0, index, index.1, Unnamed:0, index.2, encontramos que todas las columnas contienen, información duplicada.
#
# *Por lo tanto, consideramos quedarnos solo con una columna: index*

# %%
df_sin_indices = df.drop(['level_0', 'index.1', 'index.2'], axis=1)

# %%
df_sin_indices.columns
# Out:
# Index(['index', 'time', 'age', 'gender', 'Q3', 'Q4', 'Q5', 'Q6', 'Q8', 'Q11',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=242)

# %%
df_sin_indices.head(3)
# Out:
#    index  time    age gender         Q3                 Q4  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
# 2      2   924  22-24    Man   Pakistan    Master’s degree
#
#                         Q5          Q6      Q8  \
# 0                    Other  5-10 years  Python
# 1  Program/Project Manager   20+ years  Python
# 2        Software Engineer   1-3 years  Python
#
#                                                  Q11        Q13  \
# 0                                           A laptop  2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never
# 2                                           A laptop      Never
#
#                                      Q15                        Q20  \
# 0                             5-10 years  Manufacturing/Fabrication
# 1                               < 1 year  Manufacturing/Fabrication
# ...

# %% [markdown]
# * Renombramos aquellas columnas relacionadas con nuestras preguntas de investigación:

# %%
#creamos un diccionario con los nombres de las columnas:
columnas_actualizadas = {'Q3': 'country_q3', 'Q4': 'education_q4', 'Q5': 'role_q5', 'Q6': 'experience_q6','Q20': 'sector_q20', 'Q21': 'company_size_q21', 'Q25': 'anual_income_q25'}

# %%
#cambiamos los nombres de las columnas
df_sin_indices.rename(columns=columnas_actualizadas, inplace=True)

# %%
df_sin_indices.columns
# Out:
# Index(['index', 'time', 'age', 'gender', 'country_q3', 'education_q4',
#        'role_q5', 'experience_q6', 'Q8', 'Q11',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=242)

# %%
df_sin_indices.to_csv('../files/df_a_usar_2.csv')
