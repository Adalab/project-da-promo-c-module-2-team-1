# %% [markdown]
# # DataFrame con columnas unificadas

# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None

# %%
df=pd.read_csv('../files/df_a_usar_2.csv',index_col=0)
df.head(2)
# Out:
#    index  time    age gender country_q3       education_q4  \
# 0      0   910  50-54    Man      India  Bachelor’s degree
# 1      1   784  50-54    Man  Indonesia    Master’s degree
#
#                    role_q5 experience_q6      Q8  \
# 0                    Other    5-10 years  Python
# 1  Program/Project Manager     20+ years  Python
#
#                                                  Q11        Q13         Q15  \
# 0                                           A laptop  2-5 times  5-10 years
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never    < 1 year
#
#                   sector_q20      company_size_q21  Q22  \
# 0  Manufacturing/Fabrication      50-249 employees  3-4
# 1  Manufacturing/Fabrication  1000-9,999 employees  1-2
#
#                                                  Q23 anual_income_q25  \
# 0                      No (we do not use ML methods)    25,000-29,999
# 1  We are exploring ML methods (and may one day p...    60,000-69,999
#
# ...

# %% [markdown]
# ## Variables sociodemograficas definitivas

# %% [markdown]
# ### Genero

# %%
df['gender_def'] = df['gender'].replace({'Man': 'Man', 'Woman': 'Woman', 'Prefer to self-describe': 'NB', 'Nonbinary': 'NB', 'Prefer not to say': np.nan})

# %%
df['gender_def'].value_counts()
# Out:
# Man      20598
# Woman     4890
# NB         130
# Name: gender_def, dtype: int64

# %% [markdown]
# ### Edad

# %%
df['age'].describe()
# Out:
# count     25973
# unique       11
# top       25-29
# freq       4931
# Name: age, dtype: object

# %%
df['age'].value_counts()
# Out:
# 25-29    4931
# 18-21    4901
# 22-24    4694
# 30-34    3441
# 35-39    2504
# 40-44    1890
# 45-49    1375
# 50-54     964
# 55-59     592
# 60-69     553
# 70+       128
# Name: age, dtype: int64

# %% [markdown]
# ### Pais

# %%
#Vamos a crear una columna nueva para establecer a que continente pertenece cada pais de procedencia.
#Para ello debemos intalarnos la libreria 'pycountry-convert'
#pip install pycountry-convert
#Y la importamos.

import pycountry_convert as pc

def country_to_continent(country_name):
    try:
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
        return country_continent_name
    except:
        return country_name

# %%
index_iran=df.index[df['country_q3']=='Iran, Islamic Republic of...']
print('Numero de indices obtenidos:',len(index_iran))
# Out:
# Numero de indices obtenidos: 195

# %%
for i in index_iran:
    df['country_q3'].iloc[i] = "Iran"
# Out:
# /tmp/ipykernel_17748/508847129.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country_q3'].iloc[i] = "Iran"

# %%
#Procedemos a hacer lo mismo con Hong Kong.
index_hk=df.index[df['country_q3']=='Hong Kong (S.A.R.)']
print('Numero de indices obtenidos:',len(index_hk))
# Out:
# Numero de indices obtenidos: 79

# %%
for i in index_hk:
    df['country_q3'].iloc[i] = 'Hong Kong'
# Out:
# /tmp/ipykernel_17748/1251613853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country_q3'].iloc[i] = 'Hong Kong'

# %%
#Aplicar la funcion ahora que hemos sustituido Iran.
df['continent']=df['country_q3'].apply(country_to_continent)

# %%
df.columns
# Out:
# Index(['index', 'time', 'age', 'gender', 'country_q3', 'education_q4',
#        'role_q5', 'experience_q6', 'Q8', 'Q11',
#        ...
#        'Q38_B_Part_5', 'Q38_B_Part_6', 'Q38_B_Part_7', 'Q38_B_Part_8',
#        'Q38_B_Part_9', 'Q38_B_Part_10', 'Q38_B_Part_11', 'Q38_B_OTHER',
#        'gender_def', 'continent'],
#       dtype='object', length=244)

# %%
df['continent'].value_counts()
# Out:
# Asia                                     13296
# Europe                                    4327
# North America                             3260
# Africa                                    2060
# South America                             1427
# Other                                     1270
# Oceania                                    264
# I do not wish to disclose my location       69
# Name: continent, dtype: int64

# %% [markdown]
# ### Salario

# %% [markdown]
# `Es tipo object y necesitamos pasar los dolares a Euros.`

# %%
df['anual_income_q25'].dtype
# Out:
# dtype('O')

# %%
df['anual_income_q25'].value_counts()
# Out:
# $0-999              3369
# 1,000-1,999          969
# 10,000-14,999        950
# 30,000-39,999        741
# 100,000-124,999      725
# 5,000-7,499          699
# 50,000-59,999        697
# 40,000-49,999        688
# 20,000-24,999        587
# 2,000-2,999          575
# 15,000-19,999        573
# 7,500-9,999          552
# 60,000-69,999        551
# 25,000-29,999        470
# 70,000-79,999        464
# 4,000-4,999          456
# 150,000-199,999      392
# 80,000-89,999        391
# 3,000-3,999          380
# 125,000-149,999      379
# 90,000-99,999        350
# 200,000-249,999      177
# 300,000-499,999       91
# 250,000-299,999       75
# >$1,000,000           58
# $500,000-999,999      32
# Name: anual_income_q25, dtype: int64

# %%
a='$0-999'
a.split('-',)

# %% [markdown]
# ### Puesto de trabajo

# %%
df['role_q5'].value_counts()
# Out:
# Student                         6804
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2393
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1499
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: role_q5, dtype: int64
